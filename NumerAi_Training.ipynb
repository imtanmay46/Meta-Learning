# %% [markdown]
# Meta Learning
#
# NumerAi
#
# Tanmay Singh
# 2021569
# CSAI
# Class of '25

# %% [markdown]
# Importing the Dependencies

# %%
# !pip install scipy
# !pip install numpy
# !pip install pandas
# !pip install xgboost
# !pip install seaborn
# !pip install pyarrow
# !pip install numerapi
# !pip install imblearn
# !pip install catboost
# !pip install lightgbm
# !pip install matplotlib
# !pip install cloudpickle
# !pip install mplcyberpunk
# !pip install scikit-learn
# !pip install torchsummary
# Out:
# Requirement already satisfied: numerapi in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (2.19.1)
# Requirement already satisfied: requests in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from numerapi) (2.32.3)
# Requirement already satisfied: pytz in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from numerapi) (2024.1)
# Requirement already satisfied: python-dateutil in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from numerapi) (2.9.0.post0)
# Requirement already satisfied: tqdm>=4.29.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from numerapi) (4.66.5)
# Requirement already satisfied: click>=7.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from numerapi) (8.1.7)
# Requirement already satisfied: pandas>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from numerapi) (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.1.0->numerapi) (1.26.4)
# Requirement already satisfied: tzdata>=2022.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.1.0->numerapi) (2024.1)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil->numerapi) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->numerapi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->numerapi) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->numerapi) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests->numerapi) (2024.8.30)
# Requirement already satisfied: pandas in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: pyarrow in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (17.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pyarrow) (1.26.4)
# Requirement already satisfied: matplotlib in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: mplcyberpunk in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (0.7.1)
# Requirement already satisfied: matplotlib in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from mplcyberpunk) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (24.1)
# Requirement already satisfied: pillow>=8 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mplcyberpunk) (1.16.0)
# Requirement already satisfied: lightgbm in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from lightgbm) (1.11.4)
# Requirement already satisfied: scikit-learn in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: cloudpickle in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: scipy in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from scipy) (1.26.4)
# Requirement already satisfied: seaborn in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import os
import gc
import time
import json
import pickle
import numpy as np
import pandas as pd
import seaborn as sb
import xgboost as xgb
import lightgbm as lgb
import cloudpickle as cp
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
from torchsummary import summary
from torch.utils.data import DataLoader, Dataset

# %%
from tqdm import tqdm
from scipy import stats
from numerapi import NumerAPI
from scipy.stats import pearsonr
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
from sklearn.tree import *
from sklearn.metrics import *
from sklearn.ensemble import *
from sklearn.linear_model import *
from sklearn.decomposition import *
from sklearn.preprocessing import *
from sklearn.neural_network import *
from sklearn.model_selection import *
from sklearn.cluster._kmeans import KMeans
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import LocalOutlierFactor
from sklearn.neighbors import KNeighborsClassifier
from imblearn.under_sampling import RandomUnderSampler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %% [markdown]
# Loading the Dataset

# %%
NumerAi = NumerAPI()

# %%
all_datasets = NumerAi.list_datasets()
dataset_versions = list(set(d.split('/')[0] for d in all_datasets))
print("Available versions:\n", dataset_versions)
# Out:
# Available versions:
#  ['v5.0']

# %%
DATA_VERSION = "v5.0"

current_version_files = [f for f in all_datasets if f.startswith(DATA_VERSION)]
print("availbable", DATA_VERSION, "files:\n", current_version_files)
# Out:
# availbable v5.0 files:
#  ['v5.0/features.json', 'v5.0/live.parquet', 'v5.0/live_benchmark_models.parquet', 'v5.0/live_example_preds.csv', 'v5.0/live_example_preds.parquet', 'v5.0/meta_model.parquet', 'v5.0/train.parquet', 'v5.0/train_benchmark_models.parquet', 'v5.0/validation.parquet', 'v5.0/validation_benchmark_models.parquet', 'v5.0/validation_example_preds.csv', 'v5.0/validation_example_preds.parquet']

# %% [markdown]
# Creating a Feature Set

# %%
NumerAi.download_dataset(f"{DATA_VERSION}/features.json")

feature_metadata = json.load(open(f"{DATA_VERSION}/features.json"))
for metadata in feature_metadata:
  print(metadata, len(feature_metadata[metadata]))
# Out:
# 2024-11-04 08:30:05,021 INFO numerapi.utils: target file already exists
# 2024-11-04 08:30:05,022 INFO numerapi.utils: download complete
# feature_sets 17
# targets 37

# %%
feature_sets = feature_metadata["feature_sets"]
for feature_set in ["small", "medium", "all"]:
  print(feature_set, len(feature_sets[feature_set]))
# Out:
# small 42
# medium 705
# all 2376

# %%
feature_sets = feature_metadata["feature_sets"]
feature_sets.keys()
# Out:
# dict_keys(['small', 'medium', 'all', 'v2_equivalent_features', 'v3_equivalent_features', 'fncv3_features', 'intelligence', 'charisma', 'strength', 'dexterity', 'constitution', 'wisdom', 'agility', 'serenity', 'sunshine', 'rain', 'midnight'])

# %%
for feature_set in feature_sets:
  print(f'Feature Set: {feature_set:<25}', f'Size: {len(feature_sets[feature_set])}')
# Out:
# Feature Set: small                     Size: 42
# Feature Set: medium                    Size: 705
# Feature Set: all                       Size: 2376
# Feature Set: v2_equivalent_features    Size: 304
# Feature Set: v3_equivalent_features    Size: 1000
# Feature Set: fncv3_features            Size: 400
# Feature Set: intelligence              Size: 35
# Feature Set: charisma                  Size: 290
# Feature Set: strength                  Size: 135
# Feature Set: dexterity                 Size: 51
# Feature Set: constitution              Size: 335
# Feature Set: wisdom                    Size: 140
# Feature Set: agility                   Size: 145
# Feature Set: serenity                  Size: 95
# Feature Set: sunshine                  Size: 325
# Feature Set: rain                      Size: 666
# Feature Set: midnight                  Size: 244

# %% [markdown]
# Loading the Training Set, with a 'medium' feature set

# %%
feature_set = feature_sets["medium"]

NumerAi.download_dataset(f"{DATA_VERSION}/train.parquet")

train = pd.read_parquet(
    f"{DATA_VERSION}/train.parquet",
    columns=["era", "target"] + feature_set
)
# Out:
# 2024-11-04 08:30:05,600 INFO numerapi.utils: target file already exists
# 2024-11-04 08:30:05,601 INFO numerapi.utils: download complete

# %% [markdown]
# Preprocessing the Training Set

# %%
train.rename(columns=lambda x: f'feature {feature_set.index(x)}' if x in feature_set else x, inplace=True)
feature_set = train.columns.drop(["era", "target"])

# %%
train['era'] = train['era'].astype('int32')

# %%
train
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# n0007b5abb0c3a25    1    0.25          1          2          3          2
# n003bba8a98662e4    1    0.25          3          2          4          1
# n003bee128c2fcfc    1    0.75          1          2          0          2
# n0048ac83aff7194    1    0.25          1          2          3          4
# n0055a2401ba6480    1    0.25          3          2          3          4
# ...               ...     ...        ...        ...        ...        ...
# nffcc1dbdf2212e6  574    0.75          4          4          3          0
# nffde3b371d67394  574    0.25          4          4          3          0
# nfff1a1111b35e84  574    0.50          3          0          1          2
# nfff2bd38e397265  574    0.75          0          4          4          0
# nfffed717119d633  574    0.75          3          3          0          0
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# n0007b5abb0c3a25          3          2          2          2  ...
# n003bba8a98662e4          0          2          3          2  ...
# n003bee128c2fcfc          4          2          0          2  ...
# n0048ac83aff7194          0          2          3          2  ...
# n0055a2401ba6480          1          2          4          2  ...
# ...                     ...        ...        ...        ...  ...
# nffcc1dbdf2212e6          2          0          0          2  ...
# nffde3b371d67394          2          4          1          2  ...
# nfff1a1111b35e84          3          2          1          0  ...
# nfff2bd38e397265          0          4          0          1  ...
# nfffed717119d633          0          2          1          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n0007b5abb0c3a25            2            0            3            2
# n003bba8a98662e4            2            0            0            2
# n003bee128c2fcfc            2            3            3            2
# n0048ac83aff7194            2            0            2            1
# n0055a2401ba6480            2            1            3            3
# ...                       ...          ...          ...          ...
# nffcc1dbdf2212e6            4            0            4            3
# nffde3b371d67394            3            0            4            0
# nfff1a1111b35e84            4            2            4            1
# nfff2bd38e397265            0            0            4            4
# nfffed717119d633            2            3            0            2
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n0007b5abb0c3a25            4            3            2            1
# n003bba8a98662e4            0            0            2            0
# n003bee128c2fcfc            2            3            2            2
# n0048ac83aff7194            1            4            2            0
# n0055a2401ba6480            2            4            2            4
# ...                       ...          ...          ...          ...
# nffcc1dbdf2212e6            1            2            1            4
# nffde3b371d67394            2            2            2            1
# nfff1a1111b35e84            3            4            0            4
# nfff2bd38e397265            1            3            1            0
# nfffed717119d633            1            3            2            1
#
#                   feature 703  feature 704
# id
# n0007b5abb0c3a25            0            0
# n003bba8a98662e4            0            0
# n003bee128c2fcfc            2            4
# n0048ac83aff7194            2            1
# n0055a2401ba6480            1            3
# ...                       ...          ...
# nffcc1dbdf2212e6            4            2
# nffde3b371d67394            3            3
# nfff1a1111b35e84            0            4
# nfff2bd38e397265            4            0
# nfffed717119d633            4            2
#
# [2746270 rows x 707 columns]

# %%
unique_era = train['era'].unique()

# %%
train[train['era'] == unique_era[0]]
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# n0007b5abb0c3a25    1    0.25          1          2          3          2
# n003bba8a98662e4    1    0.25          3          2          4          1
# n003bee128c2fcfc    1    0.75          1          2          0          2
# n0048ac83aff7194    1    0.25          1          2          3          4
# n0055a2401ba6480    1    0.25          3          2          3          4
# ...               ...     ...        ...        ...        ...        ...
# nfe717abdac4977b    1    0.50          2          2          3          4
# nfe91b60b73a2803    1    0.50          2          2          4          0
# nfea11c308589112    1    0.75          0          2          4          0
# nff2eaeb2764bcdb    1    0.25          2          2          4          3
# nff2f12f17da5327    1    0.50          1          2          4          4
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# n0007b5abb0c3a25          3          2          2          2  ...
# n003bba8a98662e4          0          2          3          2  ...
# n003bee128c2fcfc          4          2          0          2  ...
# n0048ac83aff7194          0          2          3          2  ...
# n0055a2401ba6480          1          2          4          2  ...
# ...                     ...        ...        ...        ...  ...
# nfe717abdac4977b          1          2          3          2  ...
# nfe91b60b73a2803          0          2          1          2  ...
# nfea11c308589112          0          2          4          2  ...
# nff2eaeb2764bcdb          0          2          0          2  ...
# nff2f12f17da5327          1          2          4          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n0007b5abb0c3a25            2            0            3            2
# n003bba8a98662e4            2            0            0            2
# n003bee128c2fcfc            2            3            3            2
# n0048ac83aff7194            2            0            2            1
# n0055a2401ba6480            2            1            3            3
# ...                       ...          ...          ...          ...
# nfe717abdac4977b            2            4            0            0
# nfe91b60b73a2803            2            0            1            4
# nfea11c308589112            2            4            0            1
# nff2eaeb2764bcdb            2            1            1            1
# nff2f12f17da5327            2            4            3            1
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n0007b5abb0c3a25            4            3            2            1
# n003bba8a98662e4            0            0            2            0
# n003bee128c2fcfc            2            3            2            2
# n0048ac83aff7194            1            4            2            0
# n0055a2401ba6480            2            4            2            4
# ...                       ...          ...          ...          ...
# nfe717abdac4977b            1            4            2            0
# nfe91b60b73a2803            4            4            2            1
# nfea11c308589112            0            4            2            0
# nff2eaeb2764bcdb            0            1            2            0
# nff2f12f17da5327            3            4            2            1
#
#                   feature 703  feature 704
# id
# n0007b5abb0c3a25            0            0
# n003bba8a98662e4            0            0
# n003bee128c2fcfc            2            4
# n0048ac83aff7194            2            1
# n0055a2401ba6480            1            3
# ...                       ...          ...
# nfe717abdac4977b            0            0
# nfe91b60b73a2803            2            0
# nfea11c308589112            0            0
# nff2eaeb2764bcdb            4            0
# nff2f12f17da5327            2            1
#
# [2316 rows x 707 columns]

# %%
dataset = train
dataset
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# n0007b5abb0c3a25    1    0.25          1          2          3          2
# n003bba8a98662e4    1    0.25          3          2          4          1
# n003bee128c2fcfc    1    0.75          1          2          0          2
# n0048ac83aff7194    1    0.25          1          2          3          4
# n0055a2401ba6480    1    0.25          3          2          3          4
# ...               ...     ...        ...        ...        ...        ...
# nffcc1dbdf2212e6  574    0.75          4          4          3          0
# nffde3b371d67394  574    0.25          4          4          3          0
# nfff1a1111b35e84  574    0.50          3          0          1          2
# nfff2bd38e397265  574    0.75          0          4          4          0
# nfffed717119d633  574    0.75          3          3          0          0
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# n0007b5abb0c3a25          3          2          2          2  ...
# n003bba8a98662e4          0          2          3          2  ...
# n003bee128c2fcfc          4          2          0          2  ...
# n0048ac83aff7194          0          2          3          2  ...
# n0055a2401ba6480          1          2          4          2  ...
# ...                     ...        ...        ...        ...  ...
# nffcc1dbdf2212e6          2          0          0          2  ...
# nffde3b371d67394          2          4          1          2  ...
# nfff1a1111b35e84          3          2          1          0  ...
# nfff2bd38e397265          0          4          0          1  ...
# nfffed717119d633          0          2          1          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n0007b5abb0c3a25            2            0            3            2
# n003bba8a98662e4            2            0            0            2
# n003bee128c2fcfc            2            3            3            2
# n0048ac83aff7194            2            0            2            1
# n0055a2401ba6480            2            1            3            3
# ...                       ...          ...          ...          ...
# nffcc1dbdf2212e6            4            0            4            3
# nffde3b371d67394            3            0            4            0
# nfff1a1111b35e84            4            2            4            1
# nfff2bd38e397265            0            0            4            4
# nfffed717119d633            2            3            0            2
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n0007b5abb0c3a25            4            3            2            1
# n003bba8a98662e4            0            0            2            0
# n003bee128c2fcfc            2            3            2            2
# n0048ac83aff7194            1            4            2            0
# n0055a2401ba6480            2            4            2            4
# ...                       ...          ...          ...          ...
# nffcc1dbdf2212e6            1            2            1            4
# nffde3b371d67394            2            2            2            1
# nfff1a1111b35e84            3            4            0            4
# nfff2bd38e397265            1            3            1            0
# nfffed717119d633            1            3            2            1
#
#                   feature 703  feature 704
# id
# n0007b5abb0c3a25            0            0
# n003bba8a98662e4            0            0
# n003bee128c2fcfc            2            4
# n0048ac83aff7194            2            1
# n0055a2401ba6480            1            3
# ...                       ...          ...
# nffcc1dbdf2212e6            4            2
# nffde3b371d67394            3            3
# nfff1a1111b35e84            0            4
# nfff2bd38e397265            4            0
# nfffed717119d633            4            2
#
# [2746270 rows x 707 columns]

# %%
dataset.isna().any().any()
# Out:
# False

# %%
dataset['target'].value_counts()
# Out:
# target
# 0.50    1373108
# 0.25     550995
# 0.75     550373
# 1.00     136126
# 0.00     135668
# Name: count, dtype: int64

# %% [markdown]
# Splitting the Training Set into Training & Validation Fractions

# %%
train_df, val_df = train_test_split(train, test_size=0.2, random_state=42)

print(f'Train Split: {train_df.shape}')
print(f'Val Split: {val_df.shape}')
# Out:
# Train Split: (2197016, 707)
# Val Split: (549254, 707)

# %% [markdown]
# Clearing the unused variables using Python's Garbage Collector to free up RAM

# %%
del train
gc.collect()
# Out:
# 0

# %%
train_df['target'].value_counts()
# Out:
# target
# 0.50    1098941
# 0.25     440350
# 0.75     440295
# 1.00     108869
# 0.00     108561
# Name: count, dtype: int64

# %%
val_df['target'].value_counts()
# Out:
# target
# 0.50    274167
# 0.25    110645
# 0.75    110078
# 1.00     27257
# 0.00     27107
# Name: count, dtype: int64

# %%
train_df
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# n02ccde8415c38aa  538    0.50          1          2          0          2
# n2304b3e75684be7  538    0.75          4          3          4          0
# n8f9f03f87006ca6  301    0.25          3          0          0          0
# n329f28c70b122ca  516    0.50          1          4          1          1
# neb7b6c30352e104  336    0.50          2          1          0          2
# ...               ...     ...        ...        ...        ...        ...
# n26ad4563c77aadd   40    0.50          3          2          1          2
# nd17176101e0c0d4  369    0.50          3          0          1          3
# n68766810d412555  500    0.50          4          3          3          2
# na53b191b95a22b5  474    0.75          4          2          2          2
# n7d36f87401b3463  472    0.50          2          2          1          4
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# n02ccde8415c38aa          1          2          0          3  ...
# n2304b3e75684be7          0          4          4          0  ...
# n8f9f03f87006ca6          2          1          4          4  ...
# n329f28c70b122ca          0          2          3          0  ...
# neb7b6c30352e104          4          3          4          4  ...
# ...                     ...        ...        ...        ...  ...
# n26ad4563c77aadd          3          2          3          2  ...
# nd17176101e0c0d4          3          2          1          2  ...
# n68766810d412555          2          4          2          4  ...
# na53b191b95a22b5          3          0          0          3  ...
# n7d36f87401b3463          1          1          2          1  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n02ccde8415c38aa            4            4            1            4
# n2304b3e75684be7            2            2            4            3
# n8f9f03f87006ca6            0            2            3            1
# n329f28c70b122ca            4            1            4            3
# neb7b6c30352e104            2            4            3            4
# ...                       ...          ...          ...          ...
# n26ad4563c77aadd            2            2            4            4
# nd17176101e0c0d4            2            3            3            3
# n68766810d412555            0            2            3            0
# na53b191b95a22b5            3            3            1            4
# n7d36f87401b3463            1            3            1            1
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n02ccde8415c38aa            0            1            0            4
# n2304b3e75684be7            0            3            1            0
# n8f9f03f87006ca6            4            1            0            1
# n329f28c70b122ca            4            1            2            2
# neb7b6c30352e104            4            3            2            4
# ...                       ...          ...          ...          ...
# n26ad4563c77aadd            1            4            2            1
# nd17176101e0c0d4            3            1            0            2
# n68766810d412555            0            2            1            2
# na53b191b95a22b5            4            2            0            1
# n7d36f87401b3463            1            1            3            2
#
#                   feature 703  feature 704
# id
# n02ccde8415c38aa            3            4
# n2304b3e75684be7            2            0
# n8f9f03f87006ca6            1            1
# n329f28c70b122ca            4            0
# neb7b6c30352e104            2            3
# ...                       ...          ...
# n26ad4563c77aadd            2            3
# nd17176101e0c0d4            0            4
# n68766810d412555            2            1
# na53b191b95a22b5            2            4
# n7d36f87401b3463            1            3
#
# [2197016 rows x 707 columns]

# %%
val_df
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# nf313a6a2ba5d8ea  308    0.50          1          0          4          0
# ne898d680d03f464  331    0.50          3          0          1          1
# n986fb66ab539cb7  237    0.50          1          3          0          2
# n3d14ff5f4be25e3  125    0.50          3          3          2          2
# n1ed8fc36eda9df0   98    0.75          4          4          0          1
# ...               ...     ...        ...        ...        ...        ...
# nad4b893e7910343  108    0.50          3          0          2          1
# n4c483117a13d704  151    0.50          1          3          0          2
# nba238dc06d80658  105    0.50          1          3          0          0
# n5e84b8fff8e7781  426    0.75          2          3          1          3
# n37cfbcb6f5ef398  475    0.75          3          1          4          0
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# nf313a6a2ba5d8ea          0          2          3          4  ...
# ne898d680d03f464          2          0          3          1  ...
# n986fb66ab539cb7          3          1          3          2  ...
# n3d14ff5f4be25e3          4          2          0          0  ...
# n1ed8fc36eda9df0          1          2          2          2  ...
# ...                     ...        ...        ...        ...  ...
# nad4b893e7910343          1          2          1          3  ...
# n4c483117a13d704          2          2          1          4  ...
# nba238dc06d80658          1          2          2          2  ...
# n5e84b8fff8e7781          4          1          2          1  ...
# n37cfbcb6f5ef398          0          2          1          4  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# nf313a6a2ba5d8ea            1            0            0            4
# ne898d680d03f464            1            4            2            0
# n986fb66ab539cb7            1            3            2            4
# n3d14ff5f4be25e3            4            3            3            4
# n1ed8fc36eda9df0            2            2            0            0
# ...                       ...          ...          ...          ...
# nad4b893e7910343            0            3            2            2
# n4c483117a13d704            0            3            1            2
# nba238dc06d80658            2            0            1            3
# n5e84b8fff8e7781            3            2            4            2
# n37cfbcb6f5ef398            2            1            3            2
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# nf313a6a2ba5d8ea            0            0            0            2
# ne898d680d03f464            2            2            1            1
# n986fb66ab539cb7            2            2            0            4
# n3d14ff5f4be25e3            1            2            0            1
# n1ed8fc36eda9df0            3            3            2            3
# ...                       ...          ...          ...          ...
# nad4b893e7910343            2            1            4            3
# n4c483117a13d704            4            3            2            4
# nba238dc06d80658            3            0            2            3
# n5e84b8fff8e7781            0            1            4            3
# n37cfbcb6f5ef398            0            0            2            1
#
#                   feature 703  feature 704
# id
# nf313a6a2ba5d8ea            0            0
# ne898d680d03f464            2            3
# n986fb66ab539cb7            2            3
# n3d14ff5f4be25e3            1            2
# n1ed8fc36eda9df0            4            1
# ...                       ...          ...
# nad4b893e7910343            2            3
# n4c483117a13d704            3            1
# nba238dc06d80658            1            3
# n5e84b8fff8e7781            4            2
# n37cfbcb6f5ef398            4            0
#
# [549254 rows x 707 columns]

# %% [markdown]
# Encoding the Numeric Values in the Target into corresponding labels (class 0 to class 4)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(dataset['target'])
train_df['target'] = label_encoder.transform(train_df['target'])
val_df['target'] = label_encoder.transform(val_df['target'])

# %% [markdown]
# Label Map/Dictionary to store the mapping

# %%
labels_dict = {i: label_encoder.transform([i])[0] for i in label_encoder.classes_}
labels_dict
# Out:
# {0.0: 0, 0.25: 1, 0.5: 2, 0.75: 3, 1.0: 4}

# %%
train_df_x = train_df.drop(['target'], axis=1, inplace=False)
train_df_y = train_df['target']

# %%
train_df_x
# Out:
#                   era  feature 0  feature 1  feature 2  feature 3  feature 4  \
# id
# n02ccde8415c38aa  538          1          2          0          2          1
# n2304b3e75684be7  538          4          3          4          0          0
# n8f9f03f87006ca6  301          3          0          0          0          2
# n329f28c70b122ca  516          1          4          1          1          0
# neb7b6c30352e104  336          2          1          0          2          4
# ...               ...        ...        ...        ...        ...        ...
# n26ad4563c77aadd   40          3          2          1          2          3
# nd17176101e0c0d4  369          3          0          1          3          3
# n68766810d412555  500          4          3          3          2          2
# na53b191b95a22b5  474          4          2          2          2          3
# n7d36f87401b3463  472          2          2          1          4          1
#
#                   feature 5  feature 6  feature 7  feature 8  ...  \
# id                                                            ...
# n02ccde8415c38aa          2          0          3          4  ...
# n2304b3e75684be7          4          4          0          4  ...
# n8f9f03f87006ca6          1          4          4          3  ...
# n329f28c70b122ca          2          3          0          3  ...
# neb7b6c30352e104          3          4          4          0  ...
# ...                     ...        ...        ...        ...  ...
# n26ad4563c77aadd          2          3          2          0  ...
# nd17176101e0c0d4          2          1          2          1  ...
# n68766810d412555          4          2          4          0  ...
# na53b191b95a22b5          0          0          3          3  ...
# n7d36f87401b3463          1          2          1          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n02ccde8415c38aa            4            4            1            4
# n2304b3e75684be7            2            2            4            3
# n8f9f03f87006ca6            0            2            3            1
# n329f28c70b122ca            4            1            4            3
# neb7b6c30352e104            2            4            3            4
# ...                       ...          ...          ...          ...
# n26ad4563c77aadd            2            2            4            4
# nd17176101e0c0d4            2            3            3            3
# n68766810d412555            0            2            3            0
# na53b191b95a22b5            3            3            1            4
# n7d36f87401b3463            1            3            1            1
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n02ccde8415c38aa            0            1            0            4
# n2304b3e75684be7            0            3            1            0
# n8f9f03f87006ca6            4            1            0            1
# n329f28c70b122ca            4            1            2            2
# neb7b6c30352e104            4            3            2            4
# ...                       ...          ...          ...          ...
# n26ad4563c77aadd            1            4            2            1
# nd17176101e0c0d4            3            1            0            2
# n68766810d412555            0            2            1            2
# na53b191b95a22b5            4            2            0            1
# n7d36f87401b3463            1            1            3            2
#
#                   feature 703  feature 704
# id
# n02ccde8415c38aa            3            4
# n2304b3e75684be7            2            0
# n8f9f03f87006ca6            1            1
# n329f28c70b122ca            4            0
# neb7b6c30352e104            2            3
# ...                       ...          ...
# n26ad4563c77aadd            2            3
# nd17176101e0c0d4            0            4
# n68766810d412555            2            1
# na53b191b95a22b5            2            4
# n7d36f87401b3463            1            3
#
# [2197016 rows x 706 columns]

# %%
train_df_y
# Out:
# id
# n02ccde8415c38aa    2
# n2304b3e75684be7    3
# n8f9f03f87006ca6    1
# n329f28c70b122ca    2
# neb7b6c30352e104    2
#                    ..
# n26ad4563c77aadd    2
# nd17176101e0c0d4    2
# n68766810d412555    2
# na53b191b95a22b5    3
# n7d36f87401b3463    2
# Name: target, Length: 2197016, dtype: int64

# %%
val_df_x = val_df.drop(['target'], axis=1, inplace=False)
val_df_y = val_df['target']

# %%
val_df_x
# Out:
#                   era  feature 0  feature 1  feature 2  feature 3  feature 4  \
# id
# nf313a6a2ba5d8ea  308          1          0          4          0          0
# ne898d680d03f464  331          3          0          1          1          2
# n986fb66ab539cb7  237          1          3          0          2          3
# n3d14ff5f4be25e3  125          3          3          2          2          4
# n1ed8fc36eda9df0   98          4          4          0          1          1
# ...               ...        ...        ...        ...        ...        ...
# nad4b893e7910343  108          3          0          2          1          1
# n4c483117a13d704  151          1          3          0          2          2
# nba238dc06d80658  105          1          3          0          0          1
# n5e84b8fff8e7781  426          2          3          1          3          4
# n37cfbcb6f5ef398  475          3          1          4          0          0
#
#                   feature 5  feature 6  feature 7  feature 8  ...  \
# id                                                            ...
# nf313a6a2ba5d8ea          2          3          4          3  ...
# ne898d680d03f464          0          3          1          1  ...
# n986fb66ab539cb7          1          3          2          4  ...
# n3d14ff5f4be25e3          2          0          0          0  ...
# n1ed8fc36eda9df0          2          2          2          2  ...
# ...                     ...        ...        ...        ...  ...
# nad4b893e7910343          2          1          3          3  ...
# n4c483117a13d704          2          1          4          4  ...
# nba238dc06d80658          2          2          2          0  ...
# n5e84b8fff8e7781          1          2          1          2  ...
# n37cfbcb6f5ef398          2          1          4          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# nf313a6a2ba5d8ea            1            0            0            4
# ne898d680d03f464            1            4            2            0
# n986fb66ab539cb7            1            3            2            4
# n3d14ff5f4be25e3            4            3            3            4
# n1ed8fc36eda9df0            2            2            0            0
# ...                       ...          ...          ...          ...
# nad4b893e7910343            0            3            2            2
# n4c483117a13d704            0            3            1            2
# nba238dc06d80658            2            0            1            3
# n5e84b8fff8e7781            3            2            4            2
# n37cfbcb6f5ef398            2            1            3            2
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# nf313a6a2ba5d8ea            0            0            0            2
# ne898d680d03f464            2            2            1            1
# n986fb66ab539cb7            2            2            0            4
# n3d14ff5f4be25e3            1            2            0            1
# n1ed8fc36eda9df0            3            3            2            3
# ...                       ...          ...          ...          ...
# nad4b893e7910343            2            1            4            3
# n4c483117a13d704            4            3            2            4
# nba238dc06d80658            3            0            2            3
# n5e84b8fff8e7781            0            1            4            3
# n37cfbcb6f5ef398            0            0            2            1
#
#                   feature 703  feature 704
# id
# nf313a6a2ba5d8ea            0            0
# ne898d680d03f464            2            3
# n986fb66ab539cb7            2            3
# n3d14ff5f4be25e3            1            2
# n1ed8fc36eda9df0            4            1
# ...                       ...          ...
# nad4b893e7910343            2            3
# n4c483117a13d704            3            1
# nba238dc06d80658            1            3
# n5e84b8fff8e7781            4            2
# n37cfbcb6f5ef398            4            0
#
# [549254 rows x 706 columns]

# %%
val_df_y
# Out:
# id
# nf313a6a2ba5d8ea    2
# ne898d680d03f464    2
# n986fb66ab539cb7    2
# n3d14ff5f4be25e3    2
# n1ed8fc36eda9df0    3
#                    ..
# nad4b893e7910343    2
# n4c483117a13d704    2
# nba238dc06d80658    2
# n5e84b8fff8e7781    3
# n37cfbcb6f5ef398    3
# Name: target, Length: 549254, dtype: int64

# %%
del train_df
del val_df

gc.collect()
# Out:
# 0

# %% [markdown]
# Undersampling the training & validation fractions to ensure a more balanced dataset, since NumerAi is imbalanced/skewed towards a value of 0.5 (class 2)

# %%
undersample = RandomUnderSampler(random_state=42)

# %%
train_df_x_resampled, train_df_y_resampled = undersample.fit_resample(train_df_x, train_df_y)

# %%
val_df_x_resampled, val_df_y_resampled = undersample.fit_resample(val_df_x, val_df_y)

# %%
del train_df_x
del val_df_x
del train_df_y
del val_df_y

gc.collect()
# Out:
# 0

# %% [markdown]
# Converting data into floating type format

# %%
train_df_x_resampled = train_df_x_resampled.astype(np.float32)
val_df_x_resampled = val_df_x_resampled.astype(np.float32)

train_df_y_resampled = train_df_y_resampled.astype(np.float32)
val_df_y_resampled = val_df_y_resampled.astype(np.float32)

# %%
train_df_x_resampled
# Out:
#                     era  feature 0  feature 1  feature 2  feature 3  \
# id
# na07549d9cb0c978  247.0        2.0        4.0        0.0        3.0
# neba7f32ece3086e  365.0        0.0        3.0        2.0        4.0
# na7293ccee5af948  318.0        0.0        3.0        2.0        4.0
# nf38c63dadffa0a3  233.0        0.0        3.0        3.0        4.0
# ne31c4087a4bf180  435.0        0.0        3.0        1.0        2.0
# ...                 ...        ...        ...        ...        ...
# n4b1f1c5a85f36d3  267.0        2.0        1.0        1.0        3.0
# n54d459f5fd5dde5  250.0        4.0        1.0        1.0        0.0
# n6cf14468d0a8c44  526.0        0.0        4.0        2.0        0.0
# nb572d7239a224e5  451.0        4.0        2.0        4.0        0.0
# n04135d14c62dced  547.0        4.0        1.0        4.0        4.0
#
#                   feature 4  feature 5  feature 6  feature 7  feature 8  ...  \
# id                                                                       ...
# na07549d9cb0c978        1.0        1.0        0.0        0.0        2.0  ...
# neba7f32ece3086e        3.0        2.0        0.0        2.0        1.0  ...
# na7293ccee5af948        2.0        2.0        4.0        4.0        3.0  ...
# nf38c63dadffa0a3        0.0        2.0        4.0        4.0        1.0  ...
# ne31c4087a4bf180        4.0        0.0        1.0        3.0        0.0  ...
# ...                     ...        ...        ...        ...        ...  ...
# n4b1f1c5a85f36d3        1.0        1.0        3.0        4.0        2.0  ...
# n54d459f5fd5dde5        4.0        0.0        2.0        3.0        1.0  ...
# n6cf14468d0a8c44        0.0        4.0        1.0        1.0        3.0  ...
# nb572d7239a224e5        0.0        2.0        0.0        1.0        4.0  ...
# n04135d14c62dced        2.0        2.0        4.0        2.0        0.0  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# na07549d9cb0c978          3.0          3.0          4.0          1.0
# neba7f32ece3086e          2.0          1.0          3.0          3.0
# na7293ccee5af948          2.0          4.0          3.0          1.0
# nf38c63dadffa0a3          2.0          4.0          2.0          1.0
# ne31c4087a4bf180          1.0          2.0          3.0          2.0
# ...                       ...          ...          ...          ...
# n4b1f1c5a85f36d3          4.0          1.0          1.0          3.0
# n54d459f5fd5dde5          3.0          2.0          4.0          2.0
# n6cf14468d0a8c44          1.0          1.0          1.0          1.0
# nb572d7239a224e5          4.0          0.0          3.0          0.0
# n04135d14c62dced          2.0          4.0          0.0          0.0
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# na07549d9cb0c978          3.0          2.0          0.0          3.0
# neba7f32ece3086e          4.0          1.0          2.0          4.0
# na7293ccee5af948          4.0          2.0          0.0          4.0
# nf38c63dadffa0a3          1.0          1.0          2.0          4.0
# ne31c4087a4bf180          1.0          3.0          3.0          1.0
# ...                       ...          ...          ...          ...
# n4b1f1c5a85f36d3          1.0          3.0          0.0          4.0
# n54d459f5fd5dde5          3.0          3.0          1.0          3.0
# n6cf14468d0a8c44          3.0          3.0          1.0          1.0
# nb572d7239a224e5          0.0          1.0          4.0          0.0
# n04135d14c62dced          1.0          0.0          2.0          1.0
#
#                   feature 703  feature 704
# id
# na07549d9cb0c978          3.0          0.0
# neba7f32ece3086e          0.0          0.0
# na7293ccee5af948          1.0          1.0
# nf38c63dadffa0a3          3.0          4.0
# ne31c4087a4bf180          0.0          4.0
# ...                       ...          ...
# n4b1f1c5a85f36d3          3.0          3.0
# n54d459f5fd5dde5          2.0          0.0
# n6cf14468d0a8c44          3.0          4.0
# nb572d7239a224e5          0.0          0.0
# n04135d14c62dced          0.0          3.0
#
# [542805 rows x 706 columns]

# %%
val_df_x_resampled
# Out:
#                     era  feature 0  feature 1  feature 2  feature 3  \
# id
# ncdf26b8ce478ecf  574.0        1.0        0.0        4.0        0.0
# n4b4bf82266cda26  560.0        3.0        4.0        3.0        0.0
# n61d5d7b00dc995f  379.0        2.0        0.0        4.0        1.0
# n3162d17321ad479  569.0        0.0        4.0        4.0        0.0
# n10d10d843b6046c  292.0        0.0        4.0        2.0        0.0
# ...                 ...        ...        ...        ...        ...
# n051dbcb0462e3b6  114.0        2.0        2.0        2.0        0.0
# n40f6c9a87c5afcc    5.0        4.0        2.0        4.0        2.0
# need05ca67530d37  447.0        0.0        1.0        4.0        3.0
# nba162f3f2e3cfba  387.0        0.0        1.0        2.0        3.0
# nbd2485dc01a4c1a   28.0        0.0        2.0        3.0        0.0
#
#                   feature 4  feature 5  feature 6  feature 7  feature 8  ...  \
# id                                                                       ...
# ncdf26b8ce478ecf        0.0        3.0        2.0        3.0        0.0  ...
# n4b4bf82266cda26        3.0        2.0        2.0        4.0        4.0  ...
# n61d5d7b00dc995f        0.0        3.0        0.0        3.0        3.0  ...
# n3162d17321ad479        1.0        0.0        3.0        4.0        4.0  ...
# n10d10d843b6046c        1.0        3.0        0.0        2.0        1.0  ...
# ...                     ...        ...        ...        ...        ...  ...
# n051dbcb0462e3b6        0.0        2.0        4.0        2.0        2.0  ...
# n40f6c9a87c5afcc        1.0        2.0        3.0        2.0        0.0  ...
# need05ca67530d37        3.0        2.0        1.0        3.0        4.0  ...
# nba162f3f2e3cfba        3.0        3.0        2.0        0.0        0.0  ...
# nbd2485dc01a4c1a        2.0        2.0        1.0        2.0        4.0  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# ncdf26b8ce478ecf          1.0          1.0          0.0          4.0
# n4b4bf82266cda26          0.0          4.0          4.0          0.0
# n61d5d7b00dc995f          2.0          0.0          0.0          1.0
# n3162d17321ad479          2.0          2.0          2.0          1.0
# n10d10d843b6046c          2.0          2.0          3.0          1.0
# ...                       ...          ...          ...          ...
# n051dbcb0462e3b6          1.0          3.0          4.0          3.0
# n40f6c9a87c5afcc          2.0          3.0          2.0          4.0
# need05ca67530d37          2.0          0.0          3.0          3.0
# nba162f3f2e3cfba          1.0          0.0          4.0          3.0
# nbd2485dc01a4c1a          2.0          3.0          1.0          2.0
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# ncdf26b8ce478ecf          0.0          0.0          3.0          0.0
# n4b4bf82266cda26          4.0          4.0          2.0          2.0
# n61d5d7b00dc995f          0.0          0.0          2.0          0.0
# n3162d17321ad479          4.0          2.0          2.0          0.0
# n10d10d843b6046c          1.0          4.0          3.0          2.0
# ...                       ...          ...          ...          ...
# n051dbcb0462e3b6          4.0          4.0          2.0          3.0
# n40f6c9a87c5afcc          0.0          4.0          2.0          3.0
# need05ca67530d37          2.0          1.0          0.0          0.0
# nba162f3f2e3cfba          3.0          1.0          4.0          1.0
# nbd2485dc01a4c1a          3.0          2.0          2.0          1.0
#
#                   feature 703  feature 704
# id
# ncdf26b8ce478ecf          0.0          0.0
# n4b4bf82266cda26          4.0          0.0
# n61d5d7b00dc995f          0.0          0.0
# n3162d17321ad479          4.0          0.0
# n10d10d843b6046c          0.0          2.0
# ...                       ...          ...
# n051dbcb0462e3b6          4.0          2.0
# n40f6c9a87c5afcc          0.0          0.0
# need05ca67530d37          0.0          4.0
# nba162f3f2e3cfba          0.0          3.0
# nbd2485dc01a4c1a          4.0          4.0
#
# [135535 rows x 706 columns]

# %%
train_df_y_resampled
# Out:
# id
# na07549d9cb0c978    0.0
# neba7f32ece3086e    0.0
# na7293ccee5af948    0.0
# nf38c63dadffa0a3    0.0
# ne31c4087a4bf180    0.0
#                    ...
# n4b1f1c5a85f36d3    4.0
# n54d459f5fd5dde5    4.0
# n6cf14468d0a8c44    4.0
# nb572d7239a224e5    4.0
# n04135d14c62dced    4.0
# Name: target, Length: 542805, dtype: float32

# %%
val_df_y_resampled
# Out:
# id
# ncdf26b8ce478ecf    0.0
# n4b4bf82266cda26    0.0
# n61d5d7b00dc995f    0.0
# n3162d17321ad479    0.0
# n10d10d843b6046c    0.0
#                    ...
# n051dbcb0462e3b6    4.0
# n40f6c9a87c5afcc    4.0
# need05ca67530d37    4.0
# nba162f3f2e3cfba    4.0
# nbd2485dc01a4c1a    4.0
# Name: target, Length: 135535, dtype: float32

# %% [markdown]
# Function to extract the highly correlated features with respect to the predictions

# %%
def get_highly_correlated_features(x: pd.DataFrame, y, correlation_threshold: float = 0.03) -> list:
    if not isinstance(y, pd.Series):
        y = pd.Series(y, index=x.index)

    correlations = x.apply(lambda feature: feature.corr(y))
    highly_correlated_features = correlations[correlations.abs() > correlation_threshold].index.tolist()
    
    return highly_correlated_features

# %% [markdown]
# Function to neutralise the effect of highly correlated features with respect to the predictions by subtracting a proportion from the predictions

# %%
def neutralize_predictions(predictions: np.ndarray, x: pd.DataFrame, features_to_neutralize: list, proportion: float = 1.0) -> np.ndarray:
    predictions_df = pd.DataFrame(predictions, columns=['prediction'], index=x.index)
    neutralized_preds = predictions_df['prediction'].copy()
    
    for feature in features_to_neutralize:
        neutralizer = x[feature]
        adjustment = proportion * (neutralizer.dot(predictions_df['prediction']) / neutralizer.dot(neutralizer)) * neutralizer
        neutralized_preds -= adjustment
   
    return neutralized_preds.values

# %% [markdown]
# Calculating the class weights to ensure a more balanced training for some of the weak classifiers/experts

# %%
classes = np.unique(train_df_y_resampled)
class_weights = compute_class_weight('balanced', classes=classes, y=train_df_y_resampled)
class_weight_dict = {cls: weight for cls, weight in zip(classes, class_weights)}
sample_weights = np.array([class_weight_dict[label] for label in train_df_y_resampled])

# %% [markdown]
# Evaluation Functions

# %% [markdown]
# Function to compute Label Frequencies

# %%
def label_frequency(predictions):
    unique, counts = np.unique(predictions, return_counts=True)
    label_frequencies = dict(zip(unique, counts))
    print("Label frequencies:", label_frequencies)

# %% [markdown]
# Function to compute NumerAi Correlation

# %%
def numerai_corr(preds, target):
  ranked_preds = (preds.rank(method="average").values - 0.5) / preds.count()
  gauss_ranked_preds = stats.norm.ppf(ranked_preds)

  centered_target = target - target.mean()

  preds_p15 = np.sign(gauss_ranked_preds) * np.abs(gauss_ranked_preds) ** 1.5
  target_p15 = np.sign(centered_target) * np.abs(centered_target) ** 1.5

  return np.corrcoef(preds_p15, target_p15)[0, 1]

# %% [markdown]
# EXPERT-1 (XGBOOST CLASSIFIER)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# expert1 = xgb.XGBClassifier(
#     objective='multi:softprob',
#     num_class=5,
#     n_estimators=1000,
#     max_depth=10,
#     learning_rate=0.01,
#     random_state=42,
#     subsample=0.8,
#     colsample_bytree=0.8,
#     gamma=2,
#     min_child_weight=5,
#     reg_alpha=0.1,
#     reg_lambda=1.0,
#     eval_metric='mlogloss',
#     use_label_encoder=False
# )

# expert1.fit(train_df_x_resampled, train_df_y_resampled, sample_weight=sample_weights)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert1.pkl', 'rb') as f:
    expert1 = pickle.load(f)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Saving the Model

# %%
with open('numerai_expert1.pkl', 'wb') as f:
    pickle.dump(expert1, f)
print("Expert1 saved successfully!")
# Out:
# Expert1 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-1

# %%
expert1_pred = expert1.predict(val_df_x_resampled)

# %%
expert1_pred
# Out:
# array([0, 0, 0, ..., 4, 4, 1])

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert1_pred)
# Out:
# Label frequencies: {0: 31003, 1: 19210, 2: 34192, 3: 20200, 4: 30930}

# %%
acc = accuracy_score(expert1_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.4346847677721622

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert1_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: []

# %%
expert1_pred = neutralize_predictions(predictions=expert1_pred, x=val_df_x_resampled, features_to_neutralize=highly_correlated_features, proportion=0.01)
print("Neutralized predictions, Expert1:", expert1_pred)
# Out:
# Neutralized predictions, Expert1: [0 0 0 ... 4 4 1]

# %% [markdown]
# EXPERT-2 (RANDOM FOREST CLASSIFIER)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# expert2 = RandomForestClassifier(
#     n_estimators=1000,              
#     max_depth=10,                   
#     min_samples_split=5,            
#     min_samples_leaf=4,            
#     max_features='sqrt',           
#     bootstrap=True,               
#     class_weight='balanced',       
#     n_jobs=-1,                     
#     random_state=42,               
#     max_samples=0.9,               
#     oob_score=True,                
#     criterion='gini',              
#     verbose=1                      
# )

# expert2.fit(train_df_x_resampled, train_df_y_resampled, sample_weight=sample_weights)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert2.pkl', 'rb') as f:
    expert2 = pickle.load(f)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Saving the Model

# %%
with open('numerai_expert2.pkl', 'wb') as f:
    pickle.dump(expert2, f)
print("Expert2 saved successfully!")
# Out:
# Expert2 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-2

# %%
expert2_pred = expert2.predict(val_df_x_resampled)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=4)]: Done 1000 out of 1000 | elapsed:   12.1s finished

# %%
expert2_pred
# Out:
# array([0., 3., 0., ..., 4., 3., 1.], dtype=float32)

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert2_pred)
# Out:
# Label frequencies: {0.0: 30049, 1.0: 12036, 2.0: 47796, 3.0: 12200, 4.0: 33454}

# %%
acc = accuracy_score(expert2_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.3458442468735013

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert2_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: ['feature 42', 'feature 56', 'feature 61', 'feature 64', 'feature 65', 'feature 69', 'feature 74', 'feature 76', 'feature 81', 'feature 88', 'feature 91', 'feature 101', 'feature 113', 'feature 126', 'feature 127', 'feature 129', 'feature 133', 'feature 142', 'feature 157', 'feature 160', 'feature 168', 'feature 172', 'feature 184', 'feature 200', 'feature 208', 'feature 222', 'feature 232', 'feature 246', 'feature 263', 'feature 268', 'feature 276', 'feature 296', 'feature 302', 'feature 306', 'feature 329', 'feature 335', 'feature 346', 'feature 350', 'feature 352', 'feature 374', 'feature 406', 'feature 423', 'feature 424', 'feature 428', 'feature 431', 'feature 437', 'feature 451', 'feature 455', 'feature 459', 'feature 466', 'feature 475', 'feature 484', 'feature 501', 'feature 514', 'feature 537', 'feature 545', 'feature 546', 'feature 547', 'feature 552', 'feature 566', 'feature 573', 'feature 582', 'feature 588', 'feature 593', 'feature 615', 'feature 625', 'feature 627', 'feature 653', 'feature 657', 'feature 662', 'feature 663', 'feature 665', 'feature 674', 'feature 676', 'feature 692', 'feature 693', 'feature 703']

# %%
expert2_pred = neutralize_predictions(predictions=expert2_pred, x=val_df_x_resampled, features_to_neutralize=highly_correlated_features, proportion=0.01)
print("Neutralized predictions, Expert2:", expert2_pred)
# Out:
# Neutralized predictions, Expert2: [-0.7157442   1.4416975  -0.43838832 ...  3.3149312   2.3832166
#  -0.6667897 ]

# %% [markdown]
# EXPERT-3 (ADABOOST CLASSIFIER with DECISION TREE CLASSIFIER as BASE ESTIMATOR)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# base_estimator = DecisionTreeClassifier(
#     class_weight='balanced',                
#     max_features='sqrt',
#     max_depth=3,    
#     random_state=42         
# )

# expert3 = AdaBoostClassifier(
#     base_estimator=base_estimator, 
#     n_estimators=1000,             
#     learning_rate=0.01,           
#     algorithm='SAMME.R',           
#     random_state=42               
# )

# expert3.fit(train_df_x_resampled, train_df_y_resampled)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert3.pkl', 'rb') as f:
    expert3 = pickle.load(f)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Saving the Model

# %%
with open('numerai_expert3.pkl', 'wb') as f:
    pickle.dump(expert3, f)
print("Expert3 saved successfully!")
# Out:
# Expert3 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-3

# %%
expert3_pred = expert3.predict(val_df_x_resampled)

# %%
expert3_pred
# Out:
# array([0., 3., 4., ..., 4., 1., 1.], dtype=float32)

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert3_pred)
# Out:
# Label frequencies: {0.0: 27770, 1.0: 13593, 2.0: 44088, 3.0: 16264, 4.0: 33820}

# %%
acc = accuracy_score(expert3_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.29076622274689196

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert3_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: ['feature 4', 'feature 28', 'feature 36', 'feature 39', 'feature 49', 'feature 57', 'feature 69', 'feature 72', 'feature 124', 'feature 131', 'feature 133', 'feature 145', 'feature 146', 'feature 151', 'feature 157', 'feature 158', 'feature 159', 'feature 168', 'feature 175', 'feature 192', 'feature 219', 'feature 221', 'feature 244', 'feature 245', 'feature 254', 'feature 257', 'feature 268', 'feature 279', 'feature 299', 'feature 333', 'feature 339', 'feature 342', 'feature 344', 'feature 351', 'feature 382', 'feature 397', 'feature 402', 'feature 422', 'feature 427', 'feature 437', 'feature 442', 'feature 444', 'feature 458', 'feature 470', 'feature 477', 'feature 501', 'feature 509', 'feature 512', 'feature 533', 'feature 535', 'feature 543', 'feature 546', 'feature 547', 'feature 551', 'feature 557', 'feature 558', 'feature 582', 'feature 587', 'feature 589', 'feature 596', 'feature 618', 'feature 632', 'feature 639', 'feature 649', 'feature 656', 'feature 657', 'feature 667', 'feature 668', 'feature 675', 'feature 676', 'feature 677']

# %%
expert3_pred = neutralize_predictions(predictions=expert3_pred, x=val_df_x_resampled, features_to_neutralize=highly_correlated_features, proportion=0.01)
print("Neutralized predictions, Expert3:", expert3_pred)
# Out:
# Neutralized predictions, Expert3: [-0.7431115   1.756854    3.0819592  ...  2.7908666  -0.15753624
#   0.10444321]

# %% [markdown]
# EXPERT-4 (LOGISTIC REGRESSION)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# expert4 = LogisticRegression(
#     class_weight='balanced',
#     random_state=42,
#     solver='saga',
#     penalty='l2',
#     C=0.25,
#     tol=1e-4,
#     max_iter=500,
#     n_jobs=-1
# )

# expert4.fit(train_df_x_resampled, train_df_y_resampled)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert4.pkl', 'rb') as f:
    expert4 = pickle.load(f)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Saving the Model

# %%
with open('numerai_expert4.pkl', 'wb') as f:
    pickle.dump(expert4, f)
print("Expert4 saved successfully!")
# Out:
# Expert4 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-4

# %%
expert4_pred = expert4.predict(val_df_x_resampled)

# %%
expert4_pred
# Out:
# array([4., 1., 0., ..., 0., 3., 1.], dtype=float32)

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert4_pred)
# Out:
# Label frequencies: {0.0: 31387, 1.0: 15920, 2.0: 41091, 3.0: 16596, 4.0: 30541}

# %%
acc = accuracy_score(expert4_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.29539233408344706

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert4_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: ['feature 17', 'feature 45', 'feature 72', 'feature 133', 'feature 168', 'feature 254', 'feature 286', 'feature 287', 'feature 288', 'feature 363', 'feature 372', 'feature 379', 'feature 389', 'feature 431', 'feature 517', 'feature 546', 'feature 618', 'feature 640', 'feature 657', 'feature 666', 'feature 671', 'feature 676', 'feature 698']

# %%
expert4_pred = neutralize_predictions(predictions=expert4_pred, x=val_df_x_resampled, features_to_neutralize=highly_correlated_features, proportion=0.01)
print("Neutralized predictions, Expert4:", expert4_pred)
# Out:
# Neutralized predictions, Expert4: [ 3.742752    0.6304167  -0.18413977 ... -0.35999796  2.648405
#   0.6216319 ]

# %% [markdown]
# EXPERT-5 (CATBOOST CLASSIFIER)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# expert5 = CatBoostClassifier(
#     auto_class_weights='Balanced',
#     random_state=42,
#     iterations=500,
#     learning_rate=0.1,
#     depth=5,
#     l2_leaf_reg=3,
#     eval_metric='MultiClass',
#     early_stopping_rounds=20,
#     verbose=100
# )

# expert5.fit(train_df_x_resampled, train_df_y_resampled)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert5.pkl', 'rb') as f:
    expert5 = pickle.load(f)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Saving the Model

# %%
with open('numerai_expert5.pkl', 'wb') as f:
    pickle.dump(expert5, f)
print("Expert5 saved successfully!")
# Out:
# Expert5 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-5

# %%
expert5_pred = expert5.predict(val_df_x_resampled)

# %%
if expert5_pred.ndim > 1:
    expert5_pred = expert5_pred.ravel()

# %%
expert5_pred
# Out:
# array([0., 3., 0., ..., 4., 3., 1.])

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert5_pred)
# Out:
# Label frequencies: {0.0: 30896, 1.0: 16431, 2.0: 38741, 3.0: 17887, 4.0: 31580}

# %%
acc = accuracy_score(expert5_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.3158372376139005

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert5_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: ['feature 17', 'feature 45', 'feature 69', 'feature 72', 'feature 133', 'feature 168', 'feature 254', 'feature 268', 'feature 286', 'feature 287', 'feature 288', 'feature 363', 'feature 437', 'feature 477', 'feature 517', 'feature 546', 'feature 640', 'feature 657', 'feature 671', 'feature 676']

# %%
expert5_pred = neutralize_predictions(predictions=expert5_pred, x=val_df_x_resampled, features_to_neutralize=highly_correlated_features, proportion=0.01)
print("Neutralized predictions, Expert5:", expert5_pred)
# Out:
# Neutralized predictions, Expert5: [-0.1755911   2.67527935 -0.25528764 ...  3.73431531  2.75650493
#   0.63843689]

# %% [markdown]
# EXPERT-6 (HISTOGRAM-BASED GRADIENT BOOST CLASSIFIER)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# expert6 = HistGradientBoostingClassifier(
#     class_weight='balanced',
#     random_state=42,
#     learning_rate=0.001,
#     max_iter=500,
#     max_depth=10,
#     min_samples_leaf=20,
#     max_leaf_nodes=40,
#     l2_regularization=1.0,
#     max_bins=255,
#     early_stopping=True,
#     validation_fraction=0.1,
#     n_iter_no_change=50,
#     scoring='roc_auc_ovr',
#     loss='log_loss',
#     verbose=1
# )

# expert6.fit(train_df_x_resampled, train_df_y_resampled, sample_weight=sample_weights)
# Out:
# Binning 2.759 GB of training data: 11.875 s
# Binning 0.307 GB of validation data: 0.597 s
# Fitting gradient boosted rounds:
# [1/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61548, val score: 0.61291, in 6.228s
# [2/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61554, val score: 0.61299, in 6.027s
# [3/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61553, val score: 0.61297, in 5.913s
# [4/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61558, val score: 0.61297, in 6.014s
# [5/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61572, val score: 0.61300, in 6.091s
# [6/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61581, val score: 0.61309, in 6.083s
# [7/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61583, val score: 0.61310, in 6.094s
# [8/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61599, val score: 0.61320, in 6.015s
# [9/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61599, val score: 0.61325, in 6.155s
# [10/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61607, val score: 0.61328, in 6.234s
# [11/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61599, val score: 0.61332, in 6.175s
# [12/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61605, val score: 0.61333, in 6.088s
# [13/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61609, val score: 0.61337, in 6.161s
# [14/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61611, val score: 0.61338, in 6.248s
# [15/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61612, val score: 0.61343, in 6.174s
# [16/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61614, val score: 0.61347, in 6.078s
# [17/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61616, val score: 0.61349, in 6.402s
# [18/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61618, val score: 0.61355, in 6.163s
# [19/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61620, val score: 0.61353, in 6.251s
# [20/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61622, val score: 0.61356, in 6.290s
# [21/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61629, val score: 0.61360, in 6.089s
# [22/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61625, val score: 0.61361, in 6.406s
# [23/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61630, val score: 0.61365, in 6.219s
# [24/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61631, val score: 0.61366, in 6.274s
# [25/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61635, val score: 0.61369, in 6.070s
# [26/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61631, val score: 0.61369, in 6.277s
# [27/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61637, val score: 0.61372, in 6.253s
# [28/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61638, val score: 0.61373, in 6.243s
# [29/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61635, val score: 0.61374, in 6.499s
# [30/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61639, val score: 0.61375, in 6.325s
# [31/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61642, val score: 0.61376, in 6.266s
# [32/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61646, val score: 0.61377, in 6.387s
# [33/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61648, val score: 0.61381, in 6.410s
# [34/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61648, val score: 0.61381, in 6.555s
# [35/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61653, val score: 0.61385, in 6.395s
# [36/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61658, val score: 0.61390, in 6.234s
# [37/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61661, val score: 0.61395, in 6.393s
# [38/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61668, val score: 0.61400, in 6.507s
# [39/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61673, val score: 0.61404, in 6.373s
# [40/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61677, val score: 0.61408, in 6.279s
# [41/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61681, val score: 0.61413, in 6.504s
# [42/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61689, val score: 0.61418, in 6.349s
# [43/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61699, val score: 0.61424, in 6.413s
# [44/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61701, val score: 0.61427, in 6.621s
# [45/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61716, val score: 0.61435, in 6.443s
# [46/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61726, val score: 0.61442, in 6.389s
# [47/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61734, val score: 0.61444, in 6.549s
# [48/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61746, val score: 0.61453, in 6.519s
# [49/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61747, val score: 0.61454, in 6.580s
# [50/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61761, val score: 0.61461, in 6.401s
# [51/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61766, val score: 0.61463, in 6.543s
# [52/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61772, val score: 0.61467, in 6.551s
# [53/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61782, val score: 0.61472, in 6.393s
# [54/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61787, val score: 0.61476, in 6.697s
# [55/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61792, val score: 0.61478, in 6.552s
# [56/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61796, val score: 0.61481, in 6.489s
# [57/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61805, val score: 0.61486, in 6.685s
# [58/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61810, val score: 0.61489, in 6.677s
# [59/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61815, val score: 0.61492, in 6.662s
# [60/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61821, val score: 0.61497, in 6.628s
# [61/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61828, val score: 0.61500, in 6.620s
# [62/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61831, val score: 0.61502, in 6.580s
# [63/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61837, val score: 0.61505, in 6.831s
# [64/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61846, val score: 0.61509, in 6.578s
# [65/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61849, val score: 0.61510, in 6.655s
# [66/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61860, val score: 0.61516, in 6.913s
# [67/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61861, val score: 0.61518, in 6.667s
# [68/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61867, val score: 0.61521, in 6.645s
# [69/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61872, val score: 0.61523, in 6.635s
# [70/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61878, val score: 0.61527, in 6.657s
# [71/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61881, val score: 0.61528, in 6.743s
# [72/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61888, val score: 0.61532, in 6.648s
# [73/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61891, val score: 0.61533, in 6.802s
# [74/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61896, val score: 0.61536, in 6.644s
# [75/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61902, val score: 0.61540, in 6.794s
# [76/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61905, val score: 0.61541, in 6.857s
# [77/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61909, val score: 0.61543, in 6.954s
# [78/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61912, val score: 0.61546, in 6.814s
# [79/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61918, val score: 0.61549, in 6.787s
# [80/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61918, val score: 0.61551, in 6.611s
# [81/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61925, val score: 0.61554, in 6.921s
# [82/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61928, val score: 0.61557, in 6.788s
# [83/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61929, val score: 0.61559, in 6.777s
# [84/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61935, val score: 0.61563, in 6.849s
# [85/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61939, val score: 0.61566, in 6.822s
# [86/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61943, val score: 0.61569, in 6.887s
# [87/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61945, val score: 0.61571, in 6.916s
# [88/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61950, val score: 0.61574, in 6.835s
# [89/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61952, val score: 0.61577, in 6.949s
# [90/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61959, val score: 0.61579, in 6.892s
# [91/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61962, val score: 0.61583, in 6.869s
# [92/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61965, val score: 0.61585, in 7.078s
# [93/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61967, val score: 0.61587, in 6.910s
# [94/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61973, val score: 0.61591, in 7.057s
# [95/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61975, val score: 0.61593, in 6.968s
# [96/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61979, val score: 0.61596, in 6.949s
# [97/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61982, val score: 0.61598, in 7.006s
# [98/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61986, val score: 0.61601, in 6.925s
# [99/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61988, val score: 0.61604, in 7.078s
# [100/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61993, val score: 0.61607, in 7.052s
# [101/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61995, val score: 0.61609, in 6.968s
# [102/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61998, val score: 0.61611, in 7.220s
# [103/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62001, val score: 0.61613, in 7.002s
# [104/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62006, val score: 0.61615, in 8.989s
# [105/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62008, val score: 0.61617, in 7.203s
# [106/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62013, val score: 0.61619, in 7.208s
# [107/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62015, val score: 0.61621, in 7.016s
# [108/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62020, val score: 0.61624, in 7.236s
# [109/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62024, val score: 0.61626, in 7.080s
# [110/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62025, val score: 0.61628, in 7.232s
# [111/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62028, val score: 0.61631, in 7.083s
# [112/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62032, val score: 0.61632, in 7.303s
# [113/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62035, val score: 0.61634, in 7.164s
# [114/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62038, val score: 0.61637, in 7.126s
# [115/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62041, val score: 0.61639, in 7.193s
# [116/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62041, val score: 0.61640, in 7.218s
# [117/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62046, val score: 0.61643, in 7.244s
# [118/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62047, val score: 0.61644, in 7.182s
# [119/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62050, val score: 0.61646, in 7.191s
# [120/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62053, val score: 0.61648, in 7.191s
# [121/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62058, val score: 0.61650, in 7.271s
# [122/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62059, val score: 0.61652, in 7.212s
# [123/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62064, val score: 0.61655, in 7.172s
# [124/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62064, val score: 0.61656, in 7.498s
# [125/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62068, val score: 0.61658, in 7.213s
# [126/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62071, val score: 0.61660, in 7.367s
# [127/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62073, val score: 0.61661, in 7.449s
# [128/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62076, val score: 0.61663, in 7.483s
# [129/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62077, val score: 0.61665, in 7.345s
# [130/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62080, val score: 0.61666, in 7.489s
# [131/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62083, val score: 0.61667, in 7.330s
# [132/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62087, val score: 0.61670, in 7.375s
# [133/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62089, val score: 0.61672, in 7.394s
# [134/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62091, val score: 0.61673, in 7.448s
# [135/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62095, val score: 0.61676, in 7.510s
# [136/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62096, val score: 0.61677, in 7.411s
# [137/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62098, val score: 0.61679, in 7.512s
# [138/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62100, val score: 0.61681, in 7.482s
# [139/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62102, val score: 0.61682, in 7.485s
# [140/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62105, val score: 0.61684, in 7.726s
# [141/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62108, val score: 0.61686, in 7.460s
# [142/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62110, val score: 0.61689, in 7.424s
# [143/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62111, val score: 0.61690, in 7.444s
# [144/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62114, val score: 0.61692, in 7.463s
# [145/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62118, val score: 0.61695, in 7.585s
# [146/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62119, val score: 0.61697, in 7.564s
# [147/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62122, val score: 0.61699, in 7.716s
# [148/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62124, val score: 0.61701, in 7.692s
# [149/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62126, val score: 0.61702, in 7.466s
# [150/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62131, val score: 0.61704, in 7.719s
# [151/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62133, val score: 0.61706, in 7.717s
# [152/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62136, val score: 0.61708, in 7.485s
# [153/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62138, val score: 0.61710, in 7.666s
# [154/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62141, val score: 0.61712, in 7.552s
# [155/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62143, val score: 0.61714, in 7.478s
# [156/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62147, val score: 0.61716, in 7.700s
# [157/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62149, val score: 0.61718, in 7.827s
# [158/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62152, val score: 0.61720, in 7.574s
# [159/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62153, val score: 0.61721, in 7.628s
# [160/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62157, val score: 0.61723, in 7.764s
# [161/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62159, val score: 0.61725, in 7.821s
# [162/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62162, val score: 0.61727, in 7.868s
# [163/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62164, val score: 0.61728, in 7.668s
# [164/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62167, val score: 0.61730, in 7.760s
# [165/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62169, val score: 0.61732, in 7.770s
# [166/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62173, val score: 0.61734, in 7.606s
# [167/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62176, val score: 0.61735, in 7.735s
# [168/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62179, val score: 0.61737, in 7.901s
# [169/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62181, val score: 0.61739, in 7.676s
# [170/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62183, val score: 0.61740, in 7.772s
# [171/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62187, val score: 0.61742, in 7.683s
# [172/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62190, val score: 0.61743, in 7.732s
# [173/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62193, val score: 0.61745, in 7.798s
# [174/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62197, val score: 0.61747, in 7.877s
# [175/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62199, val score: 0.61748, in 7.800s
# [176/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62205, val score: 0.61750, in 7.860s
# [177/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62208, val score: 0.61752, in 7.996s
# [178/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62212, val score: 0.61753, in 8.011s
# [179/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62215, val score: 0.61755, in 7.944s
# [180/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62218, val score: 0.61757, in 7.840s
# [181/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62221, val score: 0.61758, in 7.907s
# [182/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62223, val score: 0.61759, in 7.962s
# [183/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62227, val score: 0.61761, in 7.941s
# [184/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62231, val score: 0.61763, in 7.989s
# [185/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62235, val score: 0.61764, in 7.973s
# [186/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62238, val score: 0.61766, in 7.993s
# [187/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62241, val score: 0.61767, in 7.952s
# [188/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62244, val score: 0.61768, in 7.933s
# [189/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62248, val score: 0.61770, in 7.860s
# [190/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62250, val score: 0.61771, in 7.989s
# [191/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62253, val score: 0.61773, in 8.174s
# [192/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62257, val score: 0.61774, in 8.254s
# [193/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62260, val score: 0.61776, in 8.140s
# [194/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62263, val score: 0.61777, in 8.050s
# [195/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62266, val score: 0.61779, in 7.975s
# [196/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62269, val score: 0.61780, in 8.115s
# [197/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62272, val score: 0.61781, in 8.069s
# [198/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62275, val score: 0.61783, in 8.023s
# [199/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62277, val score: 0.61784, in 8.055s
# [200/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62280, val score: 0.61784, in 8.129s
# [201/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62283, val score: 0.61785, in 8.142s
# [202/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62287, val score: 0.61787, in 8.042s
# [203/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62289, val score: 0.61788, in 8.043s
# [204/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62291, val score: 0.61790, in 8.210s
# [205/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62295, val score: 0.61791, in 8.288s
# [206/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62296, val score: 0.61792, in 8.234s
# [207/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62300, val score: 0.61793, in 8.376s
# [208/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62303, val score: 0.61795, in 8.370s
# [209/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62306, val score: 0.61796, in 8.249s
# [210/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62309, val score: 0.61797, in 8.449s
# [211/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62311, val score: 0.61799, in 8.253s
# [212/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62315, val score: 0.61800, in 8.226s
# [213/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62318, val score: 0.61801, in 8.312s
# [214/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62320, val score: 0.61801, in 8.314s
# [215/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62323, val score: 0.61804, in 8.251s
# [216/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62327, val score: 0.61806, in 8.264s
# [217/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62331, val score: 0.61808, in 8.287s
# [218/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62334, val score: 0.61810, in 8.286s
# [219/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62337, val score: 0.61812, in 8.263s
# [220/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62340, val score: 0.61814, in 8.374s
# [221/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62344, val score: 0.61815, in 8.327s
# [222/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62347, val score: 0.61818, in 8.261s
# [223/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62350, val score: 0.61819, in 8.602s
# [224/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62352, val score: 0.61821, in 8.469s
# [225/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62355, val score: 0.61823, in 8.477s
# [226/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62358, val score: 0.61825, in 8.257s
# [227/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62361, val score: 0.61827, in 8.487s
# [228/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62364, val score: 0.61828, in 8.385s
# [229/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62366, val score: 0.61830, in 8.335s
# [230/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62368, val score: 0.61832, in 8.407s
# [231/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62371, val score: 0.61834, in 8.346s
# [232/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62373, val score: 0.61837, in 8.415s
# [233/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62376, val score: 0.61838, in 8.394s
# [234/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62379, val score: 0.61841, in 8.238s
# [235/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62382, val score: 0.61842, in 8.527s
# [236/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62384, val score: 0.61844, in 8.419s
# [237/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62387, val score: 0.61846, in 8.536s
# [238/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62389, val score: 0.61848, in 8.749s
# [239/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62392, val score: 0.61850, in 8.501s
# [240/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62395, val score: 0.61852, in 8.384s
# [241/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62397, val score: 0.61854, in 8.560s
# [242/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62400, val score: 0.61856, in 8.825s
# [243/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62402, val score: 0.61858, in 8.540s
# [244/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62405, val score: 0.61860, in 8.591s
# [245/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62407, val score: 0.61862, in 8.647s
# [246/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62409, val score: 0.61864, in 8.720s
# [247/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62412, val score: 0.61866, in 8.850s
# [248/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62413, val score: 0.61867, in 8.821s
# [249/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62416, val score: 0.61870, in 8.768s
# [250/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62420, val score: 0.61872, in 8.833s
# [251/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62422, val score: 0.61874, in 8.761s
# [252/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62424, val score: 0.61876, in 8.678s
# [253/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62428, val score: 0.61878, in 8.713s
# [254/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62431, val score: 0.61880, in 8.669s
# [255/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62435, val score: 0.61882, in 8.762s
# [256/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62439, val score: 0.61885, in 8.684s
# [257/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62441, val score: 0.61887, in 8.968s
# [258/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62445, val score: 0.61889, in 8.745s
# [259/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62448, val score: 0.61890, in 8.725s
# [260/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62450, val score: 0.61892, in 8.820s
# [261/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62454, val score: 0.61894, in 9.156s
# [262/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62457, val score: 0.61896, in 9.000s
# [263/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62460, val score: 0.61898, in 9.064s
# [264/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62465, val score: 0.61900, in 9.015s
# [265/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62467, val score: 0.61902, in 9.028s
# [266/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62470, val score: 0.61903, in 8.964s
# [267/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62473, val score: 0.61904, in 9.112s
# [268/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62477, val score: 0.61907, in 8.971s
# [269/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62480, val score: 0.61908, in 8.975s
# [270/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62483, val score: 0.61910, in 8.952s
# [271/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62487, val score: 0.61912, in 8.990s
# [272/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62491, val score: 0.61913, in 8.915s
# [273/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62494, val score: 0.61915, in 8.916s
# [274/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62498, val score: 0.61916, in 8.916s
# [275/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62500, val score: 0.61918, in 8.978s
# [276/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62502, val score: 0.61919, in 9.264s
# [277/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62506, val score: 0.61921, in 8.889s
# [278/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62508, val score: 0.61922, in 9.126s
# [279/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62510, val score: 0.61924, in 9.103s
# [280/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62514, val score: 0.61925, in 9.314s
# [281/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62517, val score: 0.61926, in 9.061s
# [282/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62520, val score: 0.61928, in 9.243s
# [283/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62523, val score: 0.61929, in 9.037s
# [284/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62526, val score: 0.61930, in 9.077s
# [285/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62529, val score: 0.61932, in 9.197s
# [286/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62530, val score: 0.61934, in 9.122s
# [287/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62534, val score: 0.61935, in 9.236s
# [288/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62536, val score: 0.61936, in 9.080s
# [289/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62539, val score: 0.61938, in 9.143s
# [290/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62542, val score: 0.61939, in 9.124s
# [291/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62545, val score: 0.61940, in 9.397s
# [292/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62548, val score: 0.61942, in 9.274s
# [293/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62550, val score: 0.61943, in 9.366s
# [294/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62552, val score: 0.61944, in 9.334s
# [295/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62555, val score: 0.61946, in 9.334s
# [296/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62558, val score: 0.61947, in 9.536s
# [297/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62560, val score: 0.61948, in 9.567s
# [298/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62562, val score: 0.61949, in 9.269s
# [299/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62566, val score: 0.61950, in 9.110s
# [300/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62567, val score: 0.61952, in 9.333s
# [301/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62571, val score: 0.61953, in 9.273s
# [302/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62573, val score: 0.61955, in 9.406s
# [303/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62575, val score: 0.61956, in 9.283s
# [304/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62577, val score: 0.61957, in 9.262s
# [305/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62579, val score: 0.61958, in 9.421s
# [306/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62582, val score: 0.61960, in 9.387s
# [307/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62584, val score: 0.61961, in 9.198s
# [308/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62586, val score: 0.61962, in 9.361s
# [309/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62590, val score: 0.61963, in 9.398s
# [310/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62592, val score: 0.61964, in 9.248s
# [311/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62594, val score: 0.61966, in 9.305s
# [312/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62596, val score: 0.61967, in 9.495s
# [313/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62598, val score: 0.61968, in 9.320s
# [314/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62600, val score: 0.61970, in 9.391s
# [315/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62602, val score: 0.61970, in 9.410s
# [316/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62605, val score: 0.61972, in 9.519s
# [317/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62607, val score: 0.61973, in 9.418s
# [318/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62610, val score: 0.61975, in 9.505s
# [319/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62611, val score: 0.61976, in 9.324s
# [320/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62614, val score: 0.61978, in 9.304s
# [321/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62617, val score: 0.61980, in 9.332s
# [322/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62619, val score: 0.61981, in 9.393s
# [323/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62621, val score: 0.61982, in 9.474s
# [324/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62623, val score: 0.61983, in 9.516s
# [325/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62626, val score: 0.61985, in 9.472s
# [326/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62627, val score: 0.61986, in 9.470s
# [327/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62630, val score: 0.61988, in 9.559s
# [328/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62632, val score: 0.61989, in 9.563s
# [329/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62634, val score: 0.61990, in 9.407s
# [330/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62636, val score: 0.61992, in 9.483s
# [331/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62638, val score: 0.61993, in 9.445s
# [332/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62640, val score: 0.61994, in 9.527s
# [333/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62642, val score: 0.61996, in 9.838s
# [334/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62645, val score: 0.61997, in 9.385s
# [335/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62647, val score: 0.61998, in 9.471s
# [336/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62651, val score: 0.61999, in 9.481s
# [337/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62653, val score: 0.62000, in 9.640s
# [338/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62655, val score: 0.62002, in 9.753s
# [339/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62657, val score: 0.62003, in 9.768s
# [340/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62660, val score: 0.62005, in 9.660s
# [341/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62662, val score: 0.62006, in 9.828s
# [342/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62664, val score: 0.62008, in 9.878s
# [343/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62665, val score: 0.62008, in 9.654s
# [344/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62668, val score: 0.62010, in 9.855s
# [345/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62669, val score: 0.62011, in 9.723s
# [346/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62672, val score: 0.62012, in 9.838s
# [347/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62674, val score: 0.62014, in 9.811s
# [348/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62676, val score: 0.62015, in 9.803s
# [349/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62679, val score: 0.62017, in 10.099s
# [350/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62680, val score: 0.62017, in 9.858s
# [351/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62682, val score: 0.62019, in 9.935s
# [352/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62684, val score: 0.62020, in 9.876s
# [353/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62686, val score: 0.62021, in 9.927s
# [354/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62689, val score: 0.62022, in 9.757s
# [355/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62692, val score: 0.62023, in 10.039s
# [356/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62694, val score: 0.62024, in 10.005s
# [357/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62696, val score: 0.62025, in 10.104s
# [358/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62698, val score: 0.62026, in 10.276s
# [359/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62702, val score: 0.62027, in 10.104s
# [360/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62703, val score: 0.62029, in 10.457s
# [361/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62704, val score: 0.62029, in 10.048s
# [362/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62705, val score: 0.62030, in 9.997s
# [363/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62708, val score: 0.62032, in 10.242s
# [364/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62710, val score: 0.62033, in 10.261s
# [365/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62712, val score: 0.62034, in 10.032s
# [366/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62715, val score: 0.62035, in 9.989s
# [367/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62717, val score: 0.62036, in 10.291s
# [368/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62719, val score: 0.62037, in 10.591s
# [369/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62722, val score: 0.62039, in 10.293s
# [370/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62724, val score: 0.62039, in 10.379s
# [371/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62724, val score: 0.62040, in 10.172s
# [372/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62727, val score: 0.62042, in 10.192s
# [373/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62729, val score: 0.62043, in 10.367s
# [374/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62731, val score: 0.62044, in 10.399s
# [375/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62733, val score: 0.62045, in 10.496s
# [376/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62736, val score: 0.62046, in 10.229s
# [377/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62738, val score: 0.62047, in 10.415s
# [378/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62740, val score: 0.62049, in 10.783s
# [379/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62742, val score: 0.62050, in 10.787s
# [380/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62746, val score: 0.62052, in 10.401s
# [381/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62748, val score: 0.62053, in 10.303s
# [382/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62750, val score: 0.62055, in 10.417s
# [383/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62752, val score: 0.62056, in 10.375s
# [384/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62755, val score: 0.62057, in 10.537s
# [385/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62757, val score: 0.62058, in 10.336s
# [386/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62759, val score: 0.62060, in 10.335s
# [387/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62762, val score: 0.62061, in 10.265s
# [388/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62763, val score: 0.62062, in 10.487s
# [389/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62767, val score: 0.62064, in 10.535s
# [390/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62769, val score: 0.62065, in 10.275s
# [391/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62771, val score: 0.62067, in 10.346s
# [392/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62774, val score: 0.62068, in 10.287s
# [393/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62776, val score: 0.62069, in 10.393s
# [394/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62778, val score: 0.62070, in 10.275s
# [395/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62780, val score: 0.62072, in 10.272s
# [396/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62782, val score: 0.62074, in 10.565s
# [397/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62785, val score: 0.62075, in 10.412s
# [398/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62786, val score: 0.62076, in 10.363s
# [399/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62789, val score: 0.62077, in 10.395s
# [400/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62792, val score: 0.62079, in 10.591s
# [401/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62794, val score: 0.62080, in 10.308s
# [402/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62796, val score: 0.62082, in 10.572s
# [403/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62798, val score: 0.62083, in 10.589s
# [404/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62800, val score: 0.62084, in 10.452s
# [405/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62801, val score: 0.62085, in 10.658s
# [406/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62804, val score: 0.62087, in 10.653s
# [407/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62806, val score: 0.62087, in 10.474s
# [408/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62807, val score: 0.62089, in 10.641s
# [409/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62810, val score: 0.62090, in 10.755s
# [410/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62811, val score: 0.62091, in 10.437s
# [411/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62814, val score: 0.62092, in 10.417s
# [412/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62816, val score: 0.62094, in 10.654s
# [413/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62819, val score: 0.62095, in 10.759s
# [414/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62821, val score: 0.62096, in 10.553s
# [415/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62823, val score: 0.62097, in 10.817s
# [416/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62826, val score: 0.62099, in 10.993s
# [417/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62827, val score: 0.62100, in 10.861s
# [418/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62829, val score: 0.62101, in 10.967s
# [419/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62832, val score: 0.62102, in 10.981s
# [420/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62834, val score: 0.62103, in 10.803s
# [421/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62836, val score: 0.62104, in 10.827s
# [422/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62837, val score: 0.62106, in 11.011s
# [423/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62839, val score: 0.62107, in 10.980s
# [424/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62842, val score: 0.62108, in 10.890s
# [425/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62844, val score: 0.62109, in 11.067s
# [426/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62847, val score: 0.62110, in 11.026s
# [427/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62849, val score: 0.62111, in 10.982s
# [428/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62851, val score: 0.62113, in 10.733s
# [429/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62853, val score: 0.62114, in 10.909s
# [430/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62856, val score: 0.62115, in 11.022s
# [431/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62858, val score: 0.62116, in 10.831s
# [432/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62860, val score: 0.62117, in 10.986s
# [433/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62863, val score: 0.62118, in 11.150s
# [434/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62865, val score: 0.62119, in 11.096s
# [435/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62867, val score: 0.62121, in 11.184s
# [436/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62869, val score: 0.62122, in 10.963s
# [437/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62872, val score: 0.62123, in 11.166s
# [438/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62873, val score: 0.62124, in 11.019s
# [439/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62876, val score: 0.62125, in 10.998s
# [440/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62878, val score: 0.62126, in 11.163s
# [441/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62880, val score: 0.62127, in 11.169s
# [442/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62882, val score: 0.62128, in 11.205s
# [443/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62884, val score: 0.62129, in 11.037s
# [444/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62885, val score: 0.62130, in 11.144s
# [445/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62888, val score: 0.62132, in 11.178s
# [446/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62890, val score: 0.62133, in 11.201s
# [447/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62892, val score: 0.62134, in 10.824s
# [448/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62893, val score: 0.62135, in 11.073s
# [449/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62895, val score: 0.62136, in 10.927s
# [450/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62897, val score: 0.62137, in 11.113s
# [451/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62899, val score: 0.62138, in 11.162s
# [452/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62901, val score: 0.62139, in 11.200s
# [453/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62902, val score: 0.62140, in 10.839s
# [454/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62904, val score: 0.62141, in 11.201s
# [455/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62906, val score: 0.62142, in 11.132s
# [456/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62908, val score: 0.62143, in 11.149s
# [457/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62909, val score: 0.62145, in 10.931s
# [458/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62911, val score: 0.62146, in 11.159s
# [459/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62912, val score: 0.62147, in 11.203s
# [460/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62915, val score: 0.62148, in 11.192s
# [461/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62916, val score: 0.62149, in 11.171s
# [462/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62917, val score: 0.62150, in 11.442s
# [463/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62920, val score: 0.62151, in 11.256s
# [464/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62920, val score: 0.62152, in 11.450s
# [465/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62922, val score: 0.62153, in 11.300s
# [466/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62925, val score: 0.62155, in 11.364s
# [467/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62925, val score: 0.62155, in 11.239s
# [468/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62927, val score: 0.62156, in 11.432s
# [469/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62929, val score: 0.62157, in 11.379s
# [470/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62930, val score: 0.62158, in 11.159s
# [471/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62932, val score: 0.62159, in 11.266s
# [472/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62934, val score: 0.62160, in 11.141s
# [473/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62935, val score: 0.62161, in 11.246s
# [474/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62937, val score: 0.62162, in 11.145s
# [475/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62939, val score: 0.62163, in 11.546s
# [476/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62939, val score: 0.62164, in 11.422s
# [477/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62941, val score: 0.62165, in 11.206s
# [478/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62942, val score: 0.62166, in 11.538s
# [479/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62943, val score: 0.62167, in 11.202s
# [480/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62944, val score: 0.62168, in 11.238s
# [481/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62946, val score: 0.62169, in 11.264s
# [482/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62947, val score: 0.62170, in 11.143s
# [483/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62948, val score: 0.62171, in 11.168s
# [484/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62950, val score: 0.62173, in 11.496s
# [485/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62951, val score: 0.62174, in 11.210s
# [486/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62953, val score: 0.62175, in 11.610s
# [487/500] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.62953, val score: 0.62176, in 11.486s
# [488/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62955, val score: 0.62177, in 11.616s
# [489/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62955, val score: 0.62178, in 11.464s
# [490/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62957, val score: 0.62179, in 11.733s
# [491/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62958, val score: 0.62180, in 11.639s
# [492/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62959, val score: 0.62181, in 11.662s
# [493/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62961, val score: 0.62182, in 11.731s
# [494/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62962, val score: 0.62183, in 11.578s
# [495/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62964, val score: 0.62184, in 11.732s
# [496/500] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.62965, val score: 0.62185, in 11.615s
# [497/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62966, val score: 0.62186, in 11.542s
# [498/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62967, val score: 0.62187, in 12.122s
# [499/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62968, val score: 0.62188, in 11.787s
# [500/500] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.62970, val score: 0.62189, in 11.691s
# Fit 2500 trees in 4421.899 s, (100000 total leaves)
# Time spent computing histograms: 2865.706s
# Time spent finding best splits:  15.150s
# Time spent applying splits:      25.472s
# Time spent predicting:           4.024s
# HistGradientBoostingClassifier(class_weight='balanced', early_stopping=True,
#                                l2_regularization=1.0, learning_rate=0.001,
#                                max_depth=10, max_iter=500, max_leaf_nodes=40,
#                                n_iter_no_change=50, random_state=42,
#                                scoring='roc_auc_ovr', verbose=1)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert6.pkl', 'rb') as f:
    expert6 = pickle.load(f)
print("Model loaded successfully!")

# %% [markdown]
# Saving the Model

# %%
with open('numerai_expert6.pkl', 'wb') as f:
    pickle.dump(expert6, f)
print("Expert6 saved successfully!")
# Out:
# Expert6 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-6

# %%
expert6_pred = expert6.predict(val_df_x_resampled)

# %%
expert6_pred
# Out:
# array([0., 1., 4., ..., 3., 2., 0.], dtype=float32)

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert6_pred)
# Out:
# Label frequencies: {0.0: 29463, 1.0: 14034, 2.0: 43783, 3.0: 15921, 4.0: 32334}

# %%
acc = accuracy_score(expert6_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.28636883461836427

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert6_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: []

# %%
expert6_pred = neutralize_predictions(predictions=expert6_pred, x=val_df_x_resampled, features_to_neutralize=highly_correlated_features, proportion=0.01)
print("Neutralized predictions, Expert6:", expert6_pred)
# Out:
# Neutralized predictions, Expert6: [0. 1. 4. ... 3. 2. 0.]

# %% [markdown]
# META-MODEL (LIGHTGBM)

# %%
meta_model = lgb.LGBMRegressor(
    objective='regression',
    n_estimators=10000,
    learning_rate=0.01,
    max_depth=10,
    num_leaves=2**10,
    colsample_bytree=0.1,
    random_state=42
)

# %%
meta_val_x = np.column_stack((expert1_pred, expert2_pred, expert3_pred, expert4_pred, expert5_pred, expert6_pred))

# %%
meta_val_x
# Out:
# array([[ 0.        , -0.7157442 , -0.74311149,  3.74275208, -0.1755911 ,
#          0.        ],
#        [ 0.        ,  1.44169748,  1.75685406,  0.63041669,  2.67527935,
#          1.        ],
#        [ 0.        , -0.43838832,  3.08195925, -0.18413977, -0.25528764,
#          4.        ],
#        ...,
#        [ 4.        ,  3.31493115,  2.79086661, -0.35999796,  3.73431531,
#          3.        ],
#        [ 4.        ,  2.38321662, -0.15753624,  2.64840508,  2.75650493,
#          2.        ],
#        [ 1.        , -0.66678971,  0.10444321,  0.62163192,  0.63843689,
#          0.        ]])

# %%
meta_model.fit(meta_val_x, val_df_y_resampled)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005744 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1030
# [LightGBM] [Info] Number of data points in the train set: 135535, number of used features: 6
# [LightGBM] [Info] Start training from score 2.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor(colsample_bytree=0.1, learning_rate=0.01, max_depth=10,
#               n_estimators=10000, num_leaves=1024, objective='regression',
#               random_state=42)

# %% [markdown]
# Loading the Meta-Model

# %%
with open('numerai_meta_model.pkl', 'rb') as f:
    meta_model = pickle.load(f)
print("Meta Model loaded successfully!")

# %% [markdown]
# Saving the Meta-Model

# %%
with open('numerai_meta_model.pkl', 'wb') as f:
    pickle.dump(meta_model, f)
print("Meta Model saved successfully!")
# Out:
# Meta Model saved successfully!

# %% [markdown]
# Testing Performance on Trained Data

# %%
meta_y_pred = meta_model.predict(meta_val_x)

# %%
meta_y_pred
# Out:
# array([0.97908834, 1.04324704, 1.06969933, ..., 2.92813462, 3.03981607,
#        1.54116925])

# %%
bins = [0.5, 1.5, 2.5, 3.5]

rounded_predictions = np.digitize(meta_y_pred, bins)

# %%
rounded_predictions
# Out:
# array([1, 1, 1, ..., 3, 3, 2])

# %% [markdown]
# Computing Relevant Evaluation Metrics

# %%
label_frequency(rounded_predictions)
# Out:
# Label frequencies: {0: 31, 1: 36803, 2: 62113, 3: 36569, 4: 19}

# %%
acc = accuracy_score(rounded_predictions, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.2581178293429741

# %% [markdown]
# Pearson's Correlation

# %%
pearson_corr, _ = stats.pearsonr(rounded_predictions, val_df_y_resampled)
print("Pearson Correlation:", pearson_corr)
# Out:
# Pearson Correlation: 0.4540510949801483

# %% [markdown]
# Computing the NumerAi's Correlation Metric

# %%
rounded_predictions = pd.Series(rounded_predictions)

# %%
actual_corr = numerai_corr(rounded_predictions, val_df_y_resampled)
actual_corr
# Out:
# 0.45786088424761245

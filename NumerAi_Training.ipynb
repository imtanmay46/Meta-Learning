# %% [markdown]
# Meta Learning
#
# NumerAi
#
# Tanmay Singh
# 2021569
# CSAI
# Class of '25

# %% [markdown]
# Importing the Dependencies

# %%
# %pip install scipy
# %pip install numpy
# %pip install pandas
# %pip install xgboost
# %pip install seaborn
# %pip install pyarrow
# %pip install numerapi
# %pip install imblearn
# %pip install catboost
# %pip install lightgbm
# %pip install matplotlib
# %pip install cloudpickle
# %pip install mplcyberpunk
# %pip install scikit-learn
# %pip install torchsummary
# Out:
# Requirement already satisfied: scipy in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (1.12.0)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: xgboost in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: numpy in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from xgboost) (2.20.5)
# Requirement already satisfied: scipy in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from xgboost) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from seaborn) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyarrow in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (16.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pyarrow) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numerapi in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (2.19.1)
# Requirement already satisfied: requests in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from numerapi) (2.31.0)
# Requirement already satisfied: pytz in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from numerapi) (2024.1)
# Requirement already satisfied: python-dateutil in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from numerapi) (2.9.0.post0)
# Requirement already satisfied: tqdm>=4.29.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from numerapi) (4.66.2)
# Requirement already satisfied: click>=7.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from numerapi) (8.1.7)
# Requirement already satisfied: pandas>=1.1.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from numerapi) (2.2.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas>=1.1.0->numerapi) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas>=1.1.0->numerapi) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from python-dateutil->numerapi) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from requests->numerapi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from requests->numerapi) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from requests->numerapi) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from requests->numerapi) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: imblearn in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from imblearn) (0.12.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.12.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.4.1.post1)
# Requirement already satisfied: joblib>=1.1.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from imbalanced-learn->imblearn) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: catboost in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (1.2.7)
# Requirement already satisfied: graphviz in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from catboost) (3.8.3)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from catboost) (2.2.1)
# Requirement already satisfied: scipy in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from catboost) (1.12.0)
# Requirement already satisfied: plotly in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from catboost) (5.22.0)
# Requirement already satisfied: six in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->catboost) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=8 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->catboost) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from plotly->catboost) (8.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: lightgbm in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (4.5.0)
# Requirement already satisfied: numpy>=1.17.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from lightgbm) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cloudpickle in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (3.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mplcyberpunk in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (0.7.1)
# Requirement already satisfied: matplotlib in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from mplcyberpunk) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (23.2)
# Requirement already satisfied: pillow>=8 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from matplotlib->mplcyberpunk) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mplcyberpunk) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (from scikit-learn) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torchsummary in /home/nsl/gpu_env_pip/lib/python3.10/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import gc
import time
import json
import pickle
import numpy as np
import pandas as pd
import seaborn as sb
import xgboost as xgb
import lightgbm as lgb
import cloudpickle as cp
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
from torchsummary import summary
from torch.utils.data import DataLoader, Dataset

# %%
from tqdm.auto import tqdm
from scipy import stats
from numerapi import NumerAPI
from scipy.stats import pearsonr
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
from sklearn.tree import *
from sklearn.metrics import *
from sklearn.ensemble import *
from sklearn.linear_model import *
from sklearn.decomposition import *
from sklearn.preprocessing import *
from sklearn.neural_network import *
from sklearn.model_selection import *
from sklearn.cluster._kmeans import KMeans
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import LocalOutlierFactor
from sklearn.neighbors import KNeighborsClassifier
from imblearn.under_sampling import RandomUnderSampler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %% [markdown]
# Loading the Dataset

# %%
NumerAi = NumerAPI()

# %%
all_datasets = NumerAi.list_datasets()
dataset_versions = list(set(d.split('/')[0] for d in all_datasets))
print("Available versions:\n", dataset_versions)
# Out:
# Available versions:
#  ['v5.0']

# %%
DATA_VERSION = "v5.0"

current_version_files = [f for f in all_datasets if f.startswith(DATA_VERSION)]
print("availbable", DATA_VERSION, "files:\n", current_version_files)
# Out:
# availbable v5.0 files:
#  ['v5.0/features.json', 'v5.0/live.parquet', 'v5.0/live_benchmark_models.parquet', 'v5.0/live_example_preds.csv', 'v5.0/live_example_preds.parquet', 'v5.0/meta_model.parquet', 'v5.0/train.parquet', 'v5.0/train_benchmark_models.parquet', 'v5.0/validation.parquet', 'v5.0/validation_benchmark_models.parquet', 'v5.0/validation_example_preds.csv', 'v5.0/validation_example_preds.parquet']

# %% [markdown]
# Creating a Feature Set

# %%
NumerAi.download_dataset(f"{DATA_VERSION}/features.json")

feature_metadata = json.load(open(f"{DATA_VERSION}/features.json"))
for metadata in feature_metadata:
	print(metadata, len(feature_metadata[metadata]))
# Out:
# 2024-11-04 08:30:05,021 INFO numerapi.utils: target file already exists
# 2024-11-04 08:30:05,022 INFO numerapi.utils: download complete
# feature_sets 17
# targets 37

# %%
feature_sets = feature_metadata["feature_sets"]
for feature_set in ["small", "medium", "all"]:
	print(feature_set, len(feature_sets[feature_set]))
# Out:
# small 42
# medium 705
# all 2376

# %%
feature_sets = feature_metadata["feature_sets"]
feature_sets.keys()
# Out:
# dict_keys(['small', 'medium', 'all', 'v2_equivalent_features', 'v3_equivalent_features', 'fncv3_features', 'intelligence', 'charisma', 'strength', 'dexterity', 'constitution', 'wisdom', 'agility', 'serenity', 'sunshine', 'rain', 'midnight'])

# %%
for feature_set in feature_sets:
	print(f'Feature Set: {feature_set:<25}', f'Size: {len(feature_sets[feature_set])}')
# Out:
# Feature Set: small                     Size: 42
# Feature Set: medium                    Size: 705
# Feature Set: all                       Size: 2376
# Feature Set: v2_equivalent_features    Size: 304
# Feature Set: v3_equivalent_features    Size: 1000
# Feature Set: fncv3_features            Size: 400
# Feature Set: intelligence              Size: 35
# Feature Set: charisma                  Size: 290
# Feature Set: strength                  Size: 135
# Feature Set: dexterity                 Size: 51
# Feature Set: constitution              Size: 335
# Feature Set: wisdom                    Size: 140
# Feature Set: agility                   Size: 145
# Feature Set: serenity                  Size: 95
# Feature Set: sunshine                  Size: 325
# Feature Set: rain                      Size: 666
# Feature Set: midnight                  Size: 244

# %% [markdown]
# Loading the Training Set, with a 'medium' feature set

# %%
feature_set = feature_sets["medium"]

NumerAi.download_dataset(f"{DATA_VERSION}/train.parquet")

train = pd.read_parquet(
	f"{DATA_VERSION}/train.parquet",
	columns=["era", "target"] + feature_set
)
# Out:
# 2024-11-04 08:30:05,600 INFO numerapi.utils: target file already exists
# 2024-11-04 08:30:05,601 INFO numerapi.utils: download complete

# %% [markdown]
# Preprocessing the Training Set

# %%
train = pd.read_parquet(f"../data/prepared/train.parquet")

# %%
train
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# n0007b5abb0c3a25    1    0.25          1          2          3          2
# n003bba8a98662e4    1    0.25          3          2          4          1
# n003bee128c2fcfc    1    0.75          1          2          0          2
# n0048ac83aff7194    1    0.25          1          2          3          4
# n0055a2401ba6480    1    0.25          3          2          3          4
# ...               ...     ...        ...        ...        ...        ...
# nffcc1dbdf2212e6  574    0.75          4          4          3          0
# nffde3b371d67394  574    0.25          4          4          3          0
# nfff1a1111b35e84  574    0.50          3          0          1          2
# nfff2bd38e397265  574    0.75          0          4          4          0
# nfffed717119d633  574    0.75          3          3          0          0
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# n0007b5abb0c3a25          3          2          2          2  ...
# n003bba8a98662e4          0          2          3          2  ...
# n003bee128c2fcfc          4          2          0          2  ...
# n0048ac83aff7194          0          2          3          2  ...
# n0055a2401ba6480          1          2          4          2  ...
# ...                     ...        ...        ...        ...  ...
# nffcc1dbdf2212e6          2          0          0          2  ...
# nffde3b371d67394          2          4          1          2  ...
# nfff1a1111b35e84          3          2          1          0  ...
# nfff2bd38e397265          0          4          0          1  ...
# nfffed717119d633          0          2          1          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n0007b5abb0c3a25            2            0            3            2
# n003bba8a98662e4            2            0            0            2
# n003bee128c2fcfc            2            3            3            2
# n0048ac83aff7194            2            0            2            1
# n0055a2401ba6480            2            1            3            3
# ...                       ...          ...          ...          ...
# nffcc1dbdf2212e6            4            0            4            3
# nffde3b371d67394            3            0            4            0
# nfff1a1111b35e84            4            2            4            1
# nfff2bd38e397265            0            0            4            4
# nfffed717119d633            2            3            0            2
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n0007b5abb0c3a25            4            3            2            1
# n003bba8a98662e4            0            0            2            0
# n003bee128c2fcfc            2            3            2            2
# n0048ac83aff7194            1            4            2            0
# n0055a2401ba6480            2            4            2            4
# ...                       ...          ...          ...          ...
# nffcc1dbdf2212e6            1            2            1            4
# nffde3b371d67394            2            2            2            1
# nfff1a1111b35e84            3            4            0            4
# nfff2bd38e397265            1            3            1            0
# nfffed717119d633            1            3            2            1
#
#                   feature 703  feature 704
# id
# n0007b5abb0c3a25            0            0
# n003bba8a98662e4            0            0
# n003bee128c2fcfc            2            4
# n0048ac83aff7194            2            1
# n0055a2401ba6480            1            3
# ...                       ...          ...
# nffcc1dbdf2212e6            4            2
# nffde3b371d67394            3            3
# nfff1a1111b35e84            0            4
# nfff2bd38e397265            4            0
# nfffed717119d633            4            2
#
# [2746270 rows x 707 columns]

# %%
feature_set = [f for f in train.columns if f not in ["era", "target"]]
feature_set
# Out:
# ['feature 0',
#  'feature 1',
#  'feature 2',
#  'feature 3',
#  'feature 4',
#  'feature 5',
#  'feature 6',
#  'feature 7',
#  'feature 8',
#  'feature 9',
#  'feature 10',
#  'feature 11',
#  'feature 12',
#  'feature 13',
#  'feature 14',
#  'feature 15',
#  'feature 16',
#  'feature 17',
#  'feature 18',
#  'feature 19',
#  'feature 20',
#  'feature 21',
#  'feature 22',
#  'feature 23',
#  'feature 24',
#  'feature 25',
#  'feature 26',
#  'feature 27',
#  'feature 28',
#  'feature 29',
#  'feature 30',
#  'feature 31',
#  'feature 32',
#  'feature 33',
#  'feature 34',
#  'feature 35',
#  'feature 36',
#  'feature 37',
#  'feature 38',
#  'feature 39',
#  'feature 40',
#  'feature 41',
#  'feature 42',
#  'feature 43',
#  'feature 44',
#  'feature 45',
#  'feature 46',
#  'feature 47',
#  'feature 48',
#  'feature 49',
#  'feature 50',
#  'feature 51',
#  'feature 52',
#  'feature 53',
#  'feature 54',
#  'feature 55',
#  'feature 56',
#  'feature 57',
#  'feature 58',
#  'feature 59',
#  'feature 60',
#  'feature 61',
#  'feature 62',
#  'feature 63',
#  'feature 64',
#  'feature 65',
#  'feature 66',
#  'feature 67',
#  'feature 68',
#  'feature 69',
#  'feature 70',
#  'feature 71',
#  'feature 72',
#  'feature 73',
#  'feature 74',
#  'feature 75',
#  'feature 76',
#  'feature 77',
#  'feature 78',
#  'feature 79',
#  'feature 80',
#  'feature 81',
#  'feature 82',
#  'feature 83',
#  'feature 84',
#  'feature 85',
#  'feature 86',
#  'feature 87',
#  'feature 88',
#  'feature 89',
#  'feature 90',
#  'feature 91',
#  'feature 92',
#  'feature 93',
#  'feature 94',
#  'feature 95',
#  'feature 96',
#  'feature 97',
#  'feature 98',
#  'feature 99',
#  'feature 100',
#  'feature 101',
#  'feature 102',
#  'feature 103',
#  'feature 104',
#  'feature 105',
#  'feature 106',
#  'feature 107',
#  'feature 108',
#  'feature 109',
#  'feature 110',
#  'feature 111',
#  'feature 112',
#  'feature 113',
#  'feature 114',
#  'feature 115',
#  'feature 116',
#  'feature 117',
#  'feature 118',
#  'feature 119',
#  'feature 120',
#  'feature 121',
#  'feature 122',
#  'feature 123',
#  'feature 124',
#  'feature 125',
#  'feature 126',
#  'feature 127',
#  'feature 128',
#  'feature 129',
#  'feature 130',
#  'feature 131',
#  'feature 132',
#  'feature 133',
#  'feature 134',
#  'feature 135',
#  'feature 136',
#  'feature 137',
#  'feature 138',
#  'feature 139',
#  'feature 140',
#  'feature 141',
#  'feature 142',
#  'feature 143',
#  'feature 144',
#  'feature 145',
#  'feature 146',
#  'feature 147',
#  'feature 148',
#  'feature 149',
#  'feature 150',
#  'feature 151',
#  'feature 152',
#  'feature 153',
#  'feature 154',
#  'feature 155',
#  'feature 156',
#  'feature 157',
#  'feature 158',
#  'feature 159',
#  'feature 160',
#  'feature 161',
#  'feature 162',
#  'feature 163',
#  'feature 164',
#  'feature 165',
#  'feature 166',
#  'feature 167',
#  'feature 168',
#  'feature 169',
#  'feature 170',
#  'feature 171',
#  'feature 172',
#  'feature 173',
#  'feature 174',
#  'feature 175',
#  'feature 176',
#  'feature 177',
#  'feature 178',
#  'feature 179',
#  'feature 180',
#  'feature 181',
#  'feature 182',
#  'feature 183',
#  'feature 184',
#  'feature 185',
#  'feature 186',
#  'feature 187',
#  'feature 188',
#  'feature 189',
#  'feature 190',
#  'feature 191',
#  'feature 192',
#  'feature 193',
#  'feature 194',
#  'feature 195',
#  'feature 196',
#  'feature 197',
#  'feature 198',
#  'feature 199',
#  'feature 200',
#  'feature 201',
#  'feature 202',
#  'feature 203',
#  'feature 204',
#  'feature 205',
#  'feature 206',
#  'feature 207',
#  'feature 208',
#  'feature 209',
#  'feature 210',
#  'feature 211',
#  'feature 212',
#  'feature 213',
#  'feature 214',
#  'feature 215',
#  'feature 216',
#  'feature 217',
#  'feature 218',
#  'feature 219',
#  'feature 220',
#  'feature 221',
#  'feature 222',
#  'feature 223',
#  'feature 224',
#  'feature 225',
#  'feature 226',
#  'feature 227',
#  'feature 228',
#  'feature 229',
#  'feature 230',
#  'feature 231',
#  'feature 232',
#  'feature 233',
#  'feature 234',
#  'feature 235',
#  'feature 236',
#  'feature 237',
#  'feature 238',
#  'feature 239',
#  'feature 240',
#  'feature 241',
#  'feature 242',
#  'feature 243',
#  'feature 244',
#  'feature 245',
#  'feature 246',
#  'feature 247',
#  'feature 248',
#  'feature 249',
#  'feature 250',
#  'feature 251',
#  'feature 252',
#  'feature 253',
#  'feature 254',
#  'feature 255',
#  'feature 256',
#  'feature 257',
#  'feature 258',
#  'feature 259',
#  'feature 260',
#  'feature 261',
#  'feature 262',
#  'feature 263',
#  'feature 264',
#  'feature 265',
#  'feature 266',
#  'feature 267',
#  'feature 268',
#  'feature 269',
#  'feature 270',
#  'feature 271',
#  'feature 272',
#  'feature 273',
#  'feature 274',
#  'feature 275',
#  'feature 276',
#  'feature 277',
#  'feature 278',
#  'feature 279',
#  'feature 280',
#  'feature 281',
#  'feature 282',
#  'feature 283',
#  'feature 284',
#  'feature 285',
#  'feature 286',
#  'feature 287',
#  'feature 288',
#  'feature 289',
#  'feature 290',
#  'feature 291',
#  'feature 292',
#  'feature 293',
#  'feature 294',
#  'feature 295',
#  'feature 296',
#  'feature 297',
#  'feature 298',
#  'feature 299',
#  'feature 300',
#  'feature 301',
#  'feature 302',
#  'feature 303',
#  'feature 304',
#  'feature 305',
#  'feature 306',
#  'feature 307',
#  'feature 308',
#  'feature 309',
#  'feature 310',
#  'feature 311',
#  'feature 312',
#  'feature 313',
#  'feature 314',
#  'feature 315',
#  'feature 316',
#  'feature 317',
#  'feature 318',
#  'feature 319',
#  'feature 320',
#  'feature 321',
#  'feature 322',
#  'feature 323',
#  'feature 324',
#  'feature 325',
#  'feature 326',
#  'feature 327',
#  'feature 328',
#  'feature 329',
#  'feature 330',
#  'feature 331',
#  'feature 332',
#  'feature 333',
#  'feature 334',
#  'feature 335',
#  'feature 336',
#  'feature 337',
#  'feature 338',
#  'feature 339',
#  'feature 340',
#  'feature 341',
#  'feature 342',
#  'feature 343',
#  'feature 344',
#  'feature 345',
#  'feature 346',
#  'feature 347',
#  'feature 348',
#  'feature 349',
#  'feature 350',
#  'feature 351',
#  'feature 352',
#  'feature 353',
#  'feature 354',
#  'feature 355',
#  'feature 356',
#  'feature 357',
#  'feature 358',
#  'feature 359',
#  'feature 360',
#  'feature 361',
#  'feature 362',
#  'feature 363',
#  'feature 364',
#  'feature 365',
#  'feature 366',
#  'feature 367',
#  'feature 368',
#  'feature 369',
#  'feature 370',
#  'feature 371',
#  'feature 372',
#  'feature 373',
#  'feature 374',
#  'feature 375',
#  'feature 376',
#  'feature 377',
#  'feature 378',
#  'feature 379',
#  'feature 380',
#  'feature 381',
#  'feature 382',
#  'feature 383',
#  'feature 384',
#  'feature 385',
#  'feature 386',
#  'feature 387',
#  'feature 388',
#  'feature 389',
#  'feature 390',
#  'feature 391',
#  'feature 392',
#  'feature 393',
#  'feature 394',
#  'feature 395',
#  'feature 396',
#  'feature 397',
#  'feature 398',
#  'feature 399',
#  'feature 400',
#  'feature 401',
#  'feature 402',
#  'feature 403',
#  'feature 404',
#  'feature 405',
#  'feature 406',
#  'feature 407',
#  'feature 408',
#  'feature 409',
#  'feature 410',
#  'feature 411',
#  'feature 412',
#  'feature 413',
#  'feature 414',
#  'feature 415',
#  'feature 416',
#  'feature 417',
#  'feature 418',
#  'feature 419',
#  'feature 420',
#  'feature 421',
#  'feature 422',
#  'feature 423',
#  'feature 424',
#  'feature 425',
#  'feature 426',
#  'feature 427',
#  'feature 428',
#  'feature 429',
#  'feature 430',
#  'feature 431',
#  'feature 432',
#  'feature 433',
#  'feature 434',
#  'feature 435',
#  'feature 436',
#  'feature 437',
#  'feature 438',
#  'feature 439',
#  'feature 440',
#  'feature 441',
#  'feature 442',
#  'feature 443',
#  'feature 444',
#  'feature 445',
#  'feature 446',
#  'feature 447',
#  'feature 448',
#  'feature 449',
#  'feature 450',
#  'feature 451',
#  'feature 452',
#  'feature 453',
#  'feature 454',
#  'feature 455',
#  'feature 456',
#  'feature 457',
#  'feature 458',
#  'feature 459',
#  'feature 460',
#  'feature 461',
#  'feature 462',
#  'feature 463',
#  'feature 464',
#  'feature 465',
#  'feature 466',
#  'feature 467',
#  'feature 468',
#  'feature 469',
#  'feature 470',
#  'feature 471',
#  'feature 472',
#  'feature 473',
#  'feature 474',
#  'feature 475',
#  'feature 476',
#  'feature 477',
#  'feature 478',
#  'feature 479',
#  'feature 480',
#  'feature 481',
#  'feature 482',
#  'feature 483',
#  'feature 484',
#  'feature 485',
#  'feature 486',
#  'feature 487',
#  'feature 488',
#  'feature 489',
#  'feature 490',
#  'feature 491',
#  'feature 492',
#  'feature 493',
#  'feature 494',
#  'feature 495',
#  'feature 496',
#  'feature 497',
#  'feature 498',
#  'feature 499',
#  'feature 500',
#  'feature 501',
#  'feature 502',
#  'feature 503',
#  'feature 504',
#  'feature 505',
#  'feature 506',
#  'feature 507',
#  'feature 508',
#  'feature 509',
#  'feature 510',
#  'feature 511',
#  'feature 512',
#  'feature 513',
#  'feature 514',
#  'feature 515',
#  'feature 516',
#  'feature 517',
#  'feature 518',
#  'feature 519',
#  'feature 520',
#  'feature 521',
#  'feature 522',
#  'feature 523',
#  'feature 524',
#  'feature 525',
#  'feature 526',
#  'feature 527',
#  'feature 528',
#  'feature 529',
#  'feature 530',
#  'feature 531',
#  'feature 532',
#  'feature 533',
#  'feature 534',
#  'feature 535',
#  'feature 536',
#  'feature 537',
#  'feature 538',
#  'feature 539',
#  'feature 540',
#  'feature 541',
#  'feature 542',
#  'feature 543',
#  'feature 544',
#  'feature 545',
#  'feature 546',
#  'feature 547',
#  'feature 548',
#  'feature 549',
#  'feature 550',
#  'feature 551',
#  'feature 552',
#  'feature 553',
#  'feature 554',
#  'feature 555',
#  'feature 556',
#  'feature 557',
#  'feature 558',
#  'feature 559',
#  'feature 560',
#  'feature 561',
#  'feature 562',
#  'feature 563',
#  'feature 564',
#  'feature 565',
#  'feature 566',
#  'feature 567',
#  'feature 568',
#  'feature 569',
#  'feature 570',
#  'feature 571',
#  'feature 572',
#  'feature 573',
#  'feature 574',
#  'feature 575',
#  'feature 576',
#  'feature 577',
#  'feature 578',
#  'feature 579',
#  'feature 580',
#  'feature 581',
#  'feature 582',
#  'feature 583',
#  'feature 584',
#  'feature 585',
#  'feature 586',
#  'feature 587',
#  'feature 588',
#  'feature 589',
#  'feature 590',
#  'feature 591',
#  'feature 592',
#  'feature 593',
#  'feature 594',
#  'feature 595',
#  'feature 596',
#  'feature 597',
#  'feature 598',
#  'feature 599',
#  'feature 600',
#  'feature 601',
#  'feature 602',
#  'feature 603',
#  'feature 604',
#  'feature 605',
#  'feature 606',
#  'feature 607',
#  'feature 608',
#  'feature 609',
#  'feature 610',
#  'feature 611',
#  'feature 612',
#  'feature 613',
#  'feature 614',
#  'feature 615',
#  'feature 616',
#  'feature 617',
#  'feature 618',
#  'feature 619',
#  'feature 620',
#  'feature 621',
#  'feature 622',
#  'feature 623',
#  'feature 624',
#  'feature 625',
#  'feature 626',
#  'feature 627',
#  'feature 628',
#  'feature 629',
#  'feature 630',
#  'feature 631',
#  'feature 632',
#  'feature 633',
#  'feature 634',
#  'feature 635',
#  'feature 636',
#  'feature 637',
#  'feature 638',
#  'feature 639',
#  'feature 640',
#  'feature 641',
#  'feature 642',
#  'feature 643',
#  'feature 644',
#  'feature 645',
#  'feature 646',
#  'feature 647',
#  'feature 648',
#  'feature 649',
#  'feature 650',
#  'feature 651',
#  'feature 652',
#  'feature 653',
#  'feature 654',
#  'feature 655',
#  'feature 656',
#  'feature 657',
#  'feature 658',
#  'feature 659',
#  'feature 660',
#  'feature 661',
#  'feature 662',
#  'feature 663',
#  'feature 664',
#  'feature 665',
#  'feature 666',
#  'feature 667',
#  'feature 668',
#  'feature 669',
#  'feature 670',
#  'feature 671',
#  'feature 672',
#  'feature 673',
#  'feature 674',
#  'feature 675',
#  'feature 676',
#  'feature 677',
#  'feature 678',
#  'feature 679',
#  'feature 680',
#  'feature 681',
#  'feature 682',
#  'feature 683',
#  'feature 684',
#  'feature 685',
#  'feature 686',
#  'feature 687',
#  'feature 688',
#  'feature 689',
#  'feature 690',
#  'feature 691',
#  'feature 692',
#  'feature 693',
#  'feature 694',
#  'feature 695',
#  'feature 696',
#  'feature 697',
#  'feature 698',
#  'feature 699',
#  'feature 700',
#  'feature 701',
#  'feature 702',
#  'feature 703',
#  'feature 704']

# %%
train.rename(columns=lambda x: f'feature {feature_set.index(x)}' if x in feature_set else x, inplace=True)
feature_set = train.columns.drop(["era", "target"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 train.rename(columns=lambda x: f'feature {feature_set.index(x)}' if x in feature_set else x, inplace=True)
# ----> 2 feature_set = train.columns.drop(["era", "target"])
#
# File ~/gpu_env_pip/lib64/python3.10/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['era', 'target'] not found in axis"

# %%
train['era'] = train['era'].astype('int32')

# %%
train
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# n0007b5abb0c3a25    1    0.25          1          2          3          2
# n003bba8a98662e4    1    0.25          3          2          4          1
# n003bee128c2fcfc    1    0.75          1          2          0          2
# n0048ac83aff7194    1    0.25          1          2          3          4
# n0055a2401ba6480    1    0.25          3          2          3          4
# ...               ...     ...        ...        ...        ...        ...
# nffcc1dbdf2212e6  574    0.75          4          4          3          0
# nffde3b371d67394  574    0.25          4          4          3          0
# nfff1a1111b35e84  574    0.50          3          0          1          2
# nfff2bd38e397265  574    0.75          0          4          4          0
# nfffed717119d633  574    0.75          3          3          0          0
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# n0007b5abb0c3a25          3          2          2          2  ...
# n003bba8a98662e4          0          2          3          2  ...
# n003bee128c2fcfc          4          2          0          2  ...
# n0048ac83aff7194          0          2          3          2  ...
# n0055a2401ba6480          1          2          4          2  ...
# ...                     ...        ...        ...        ...  ...
# nffcc1dbdf2212e6          2          0          0          2  ...
# nffde3b371d67394          2          4          1          2  ...
# nfff1a1111b35e84          3          2          1          0  ...
# nfff2bd38e397265          0          4          0          1  ...
# nfffed717119d633          0          2          1          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n0007b5abb0c3a25            2            0            3            2
# n003bba8a98662e4            2            0            0            2
# n003bee128c2fcfc            2            3            3            2
# n0048ac83aff7194            2            0            2            1
# n0055a2401ba6480            2            1            3            3
# ...                       ...          ...          ...          ...
# nffcc1dbdf2212e6            4            0            4            3
# nffde3b371d67394            3            0            4            0
# nfff1a1111b35e84            4            2            4            1
# nfff2bd38e397265            0            0            4            4
# nfffed717119d633            2            3            0            2
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n0007b5abb0c3a25            4            3            2            1
# n003bba8a98662e4            0            0            2            0
# n003bee128c2fcfc            2            3            2            2
# n0048ac83aff7194            1            4            2            0
# n0055a2401ba6480            2            4            2            4
# ...                       ...          ...          ...          ...
# nffcc1dbdf2212e6            1            2            1            4
# nffde3b371d67394            2            2            2            1
# nfff1a1111b35e84            3            4            0            4
# nfff2bd38e397265            1            3            1            0
# nfffed717119d633            1            3            2            1
#
#                   feature 703  feature 704
# id
# n0007b5abb0c3a25            0            0
# n003bba8a98662e4            0            0
# n003bee128c2fcfc            2            4
# n0048ac83aff7194            2            1
# n0055a2401ba6480            1            3
# ...                       ...          ...
# nffcc1dbdf2212e6            4            2
# nffde3b371d67394            3            3
# nfff1a1111b35e84            0            4
# nfff2bd38e397265            4            0
# nfffed717119d633            4            2
#
# [2746270 rows x 707 columns]

# %%
unique_era = train['era'].unique()

# %%
train[train['era'] == unique_era[0]]
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# n0007b5abb0c3a25    1    0.25          1          2          3          2
# n003bba8a98662e4    1    0.25          3          2          4          1
# n003bee128c2fcfc    1    0.75          1          2          0          2
# n0048ac83aff7194    1    0.25          1          2          3          4
# n0055a2401ba6480    1    0.25          3          2          3          4
# ...               ...     ...        ...        ...        ...        ...
# nfe717abdac4977b    1    0.50          2          2          3          4
# nfe91b60b73a2803    1    0.50          2          2          4          0
# nfea11c308589112    1    0.75          0          2          4          0
# nff2eaeb2764bcdb    1    0.25          2          2          4          3
# nff2f12f17da5327    1    0.50          1          2          4          4
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# n0007b5abb0c3a25          3          2          2          2  ...
# n003bba8a98662e4          0          2          3          2  ...
# n003bee128c2fcfc          4          2          0          2  ...
# n0048ac83aff7194          0          2          3          2  ...
# n0055a2401ba6480          1          2          4          2  ...
# ...                     ...        ...        ...        ...  ...
# nfe717abdac4977b          1          2          3          2  ...
# nfe91b60b73a2803          0          2          1          2  ...
# nfea11c308589112          0          2          4          2  ...
# nff2eaeb2764bcdb          0          2          0          2  ...
# nff2f12f17da5327          1          2          4          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n0007b5abb0c3a25            2            0            3            2
# n003bba8a98662e4            2            0            0            2
# n003bee128c2fcfc            2            3            3            2
# n0048ac83aff7194            2            0            2            1
# n0055a2401ba6480            2            1            3            3
# ...                       ...          ...          ...          ...
# nfe717abdac4977b            2            4            0            0
# nfe91b60b73a2803            2            0            1            4
# nfea11c308589112            2            4            0            1
# nff2eaeb2764bcdb            2            1            1            1
# nff2f12f17da5327            2            4            3            1
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n0007b5abb0c3a25            4            3            2            1
# n003bba8a98662e4            0            0            2            0
# n003bee128c2fcfc            2            3            2            2
# n0048ac83aff7194            1            4            2            0
# n0055a2401ba6480            2            4            2            4
# ...                       ...          ...          ...          ...
# nfe717abdac4977b            1            4            2            0
# nfe91b60b73a2803            4            4            2            1
# nfea11c308589112            0            4            2            0
# nff2eaeb2764bcdb            0            1            2            0
# nff2f12f17da5327            3            4            2            1
#
#                   feature 703  feature 704
# id
# n0007b5abb0c3a25            0            0
# n003bba8a98662e4            0            0
# n003bee128c2fcfc            2            4
# n0048ac83aff7194            2            1
# n0055a2401ba6480            1            3
# ...                       ...          ...
# nfe717abdac4977b            0            0
# nfe91b60b73a2803            2            0
# nfea11c308589112            0            0
# nff2eaeb2764bcdb            4            0
# nff2f12f17da5327            2            1
#
# [2316 rows x 707 columns]

# %%
dataset = train
dataset
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# n0007b5abb0c3a25    1    0.25          1          2          3          2
# n003bba8a98662e4    1    0.25          3          2          4          1
# n003bee128c2fcfc    1    0.75          1          2          0          2
# n0048ac83aff7194    1    0.25          1          2          3          4
# n0055a2401ba6480    1    0.25          3          2          3          4
# ...               ...     ...        ...        ...        ...        ...
# nffcc1dbdf2212e6  574    0.75          4          4          3          0
# nffde3b371d67394  574    0.25          4          4          3          0
# nfff1a1111b35e84  574    0.50          3          0          1          2
# nfff2bd38e397265  574    0.75          0          4          4          0
# nfffed717119d633  574    0.75          3          3          0          0
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# n0007b5abb0c3a25          3          2          2          2  ...
# n003bba8a98662e4          0          2          3          2  ...
# n003bee128c2fcfc          4          2          0          2  ...
# n0048ac83aff7194          0          2          3          2  ...
# n0055a2401ba6480          1          2          4          2  ...
# ...                     ...        ...        ...        ...  ...
# nffcc1dbdf2212e6          2          0          0          2  ...
# nffde3b371d67394          2          4          1          2  ...
# nfff1a1111b35e84          3          2          1          0  ...
# nfff2bd38e397265          0          4          0          1  ...
# nfffed717119d633          0          2          1          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n0007b5abb0c3a25            2            0            3            2
# n003bba8a98662e4            2            0            0            2
# n003bee128c2fcfc            2            3            3            2
# n0048ac83aff7194            2            0            2            1
# n0055a2401ba6480            2            1            3            3
# ...                       ...          ...          ...          ...
# nffcc1dbdf2212e6            4            0            4            3
# nffde3b371d67394            3            0            4            0
# nfff1a1111b35e84            4            2            4            1
# nfff2bd38e397265            0            0            4            4
# nfffed717119d633            2            3            0            2
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n0007b5abb0c3a25            4            3            2            1
# n003bba8a98662e4            0            0            2            0
# n003bee128c2fcfc            2            3            2            2
# n0048ac83aff7194            1            4            2            0
# n0055a2401ba6480            2            4            2            4
# ...                       ...          ...          ...          ...
# nffcc1dbdf2212e6            1            2            1            4
# nffde3b371d67394            2            2            2            1
# nfff1a1111b35e84            3            4            0            4
# nfff2bd38e397265            1            3            1            0
# nfffed717119d633            1            3            2            1
#
#                   feature 703  feature 704
# id
# n0007b5abb0c3a25            0            0
# n003bba8a98662e4            0            0
# n003bee128c2fcfc            2            4
# n0048ac83aff7194            2            1
# n0055a2401ba6480            1            3
# ...                       ...          ...
# nffcc1dbdf2212e6            4            2
# nffde3b371d67394            3            3
# nfff1a1111b35e84            0            4
# nfff2bd38e397265            4            0
# nfffed717119d633            4            2
#
# [2746270 rows x 707 columns]

# %%
dataset.isna().any().any()
# Out:
# False

# %%
dataset['target'].value_counts()
# Out:
# target
# 0.50    1373108
# 0.25     550995
# 0.75     550373
# 1.00     136126
# 0.00     135668
# Name: count, dtype: int64

# %% [markdown]
# Splitting the Training Set into Training & Validation Fractions

# %%
train_df, val_df = train_test_split(train, test_size=0.2, random_state=42)

print(f'Train Split: {train_df.shape}')
print(f'Val Split: {val_df.shape}')
# Out:
# Train Split: (2197016, 707)
# Val Split: (549254, 707)

# %% [markdown]
# Clearing the unused variables using Python's Garbage Collector to free up RAM

# %%
del train
gc.collect()
# Out:
# 0

# %%
train_df['target'].value_counts()
# Out:
# target
# 0.50    1098941
# 0.25     440350
# 0.75     440295
# 1.00     108869
# 0.00     108561
# Name: count, dtype: int64

# %%
val_df['target'].value_counts()
# Out:
# target
# 0.50    274167
# 0.25    110645
# 0.75    110078
# 1.00     27257
# 0.00     27107
# Name: count, dtype: int64

# %%
train_df
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# n02ccde8415c38aa  538    0.50          1          2          0          2
# n2304b3e75684be7  538    0.75          4          3          4          0
# n8f9f03f87006ca6  301    0.25          3          0          0          0
# n329f28c70b122ca  516    0.50          1          4          1          1
# neb7b6c30352e104  336    0.50          2          1          0          2
# ...               ...     ...        ...        ...        ...        ...
# n26ad4563c77aadd   40    0.50          3          2          1          2
# nd17176101e0c0d4  369    0.50          3          0          1          3
# n68766810d412555  500    0.50          4          3          3          2
# na53b191b95a22b5  474    0.75          4          2          2          2
# n7d36f87401b3463  472    0.50          2          2          1          4
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# n02ccde8415c38aa          1          2          0          3  ...
# n2304b3e75684be7          0          4          4          0  ...
# n8f9f03f87006ca6          2          1          4          4  ...
# n329f28c70b122ca          0          2          3          0  ...
# neb7b6c30352e104          4          3          4          4  ...
# ...                     ...        ...        ...        ...  ...
# n26ad4563c77aadd          3          2          3          2  ...
# nd17176101e0c0d4          3          2          1          2  ...
# n68766810d412555          2          4          2          4  ...
# na53b191b95a22b5          3          0          0          3  ...
# n7d36f87401b3463          1          1          2          1  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n02ccde8415c38aa            4            4            1            4
# n2304b3e75684be7            2            2            4            3
# n8f9f03f87006ca6            0            2            3            1
# n329f28c70b122ca            4            1            4            3
# neb7b6c30352e104            2            4            3            4
# ...                       ...          ...          ...          ...
# n26ad4563c77aadd            2            2            4            4
# nd17176101e0c0d4            2            3            3            3
# n68766810d412555            0            2            3            0
# na53b191b95a22b5            3            3            1            4
# n7d36f87401b3463            1            3            1            1
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n02ccde8415c38aa            0            1            0            4
# n2304b3e75684be7            0            3            1            0
# n8f9f03f87006ca6            4            1            0            1
# n329f28c70b122ca            4            1            2            2
# neb7b6c30352e104            4            3            2            4
# ...                       ...          ...          ...          ...
# n26ad4563c77aadd            1            4            2            1
# nd17176101e0c0d4            3            1            0            2
# n68766810d412555            0            2            1            2
# na53b191b95a22b5            4            2            0            1
# n7d36f87401b3463            1            1            3            2
#
#                   feature 703  feature 704
# id
# n02ccde8415c38aa            3            4
# n2304b3e75684be7            2            0
# n8f9f03f87006ca6            1            1
# n329f28c70b122ca            4            0
# neb7b6c30352e104            2            3
# ...                       ...          ...
# n26ad4563c77aadd            2            3
# nd17176101e0c0d4            0            4
# n68766810d412555            2            1
# na53b191b95a22b5            2            4
# n7d36f87401b3463            1            3
#
# [2197016 rows x 707 columns]

# %%
val_df
# Out:
#                   era  target  feature 0  feature 1  feature 2  feature 3  \
# id
# nf313a6a2ba5d8ea  308    0.50          1          0          4          0
# ne898d680d03f464  331    0.50          3          0          1          1
# n986fb66ab539cb7  237    0.50          1          3          0          2
# n3d14ff5f4be25e3  125    0.50          3          3          2          2
# n1ed8fc36eda9df0   98    0.75          4          4          0          1
# ...               ...     ...        ...        ...        ...        ...
# nad4b893e7910343  108    0.50          3          0          2          1
# n4c483117a13d704  151    0.50          1          3          0          2
# nba238dc06d80658  105    0.50          1          3          0          0
# n5e84b8fff8e7781  426    0.75          2          3          1          3
# n37cfbcb6f5ef398  475    0.75          3          1          4          0
#
#                   feature 4  feature 5  feature 6  feature 7  ...  \
# id                                                            ...
# nf313a6a2ba5d8ea          0          2          3          4  ...
# ne898d680d03f464          2          0          3          1  ...
# n986fb66ab539cb7          3          1          3          2  ...
# n3d14ff5f4be25e3          4          2          0          0  ...
# n1ed8fc36eda9df0          1          2          2          2  ...
# ...                     ...        ...        ...        ...  ...
# nad4b893e7910343          1          2          1          3  ...
# n4c483117a13d704          2          2          1          4  ...
# nba238dc06d80658          1          2          2          2  ...
# n5e84b8fff8e7781          4          1          2          1  ...
# n37cfbcb6f5ef398          0          2          1          4  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# nf313a6a2ba5d8ea            1            0            0            4
# ne898d680d03f464            1            4            2            0
# n986fb66ab539cb7            1            3            2            4
# n3d14ff5f4be25e3            4            3            3            4
# n1ed8fc36eda9df0            2            2            0            0
# ...                       ...          ...          ...          ...
# nad4b893e7910343            0            3            2            2
# n4c483117a13d704            0            3            1            2
# nba238dc06d80658            2            0            1            3
# n5e84b8fff8e7781            3            2            4            2
# n37cfbcb6f5ef398            2            1            3            2
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# nf313a6a2ba5d8ea            0            0            0            2
# ne898d680d03f464            2            2            1            1
# n986fb66ab539cb7            2            2            0            4
# n3d14ff5f4be25e3            1            2            0            1
# n1ed8fc36eda9df0            3            3            2            3
# ...                       ...          ...          ...          ...
# nad4b893e7910343            2            1            4            3
# n4c483117a13d704            4            3            2            4
# nba238dc06d80658            3            0            2            3
# n5e84b8fff8e7781            0            1            4            3
# n37cfbcb6f5ef398            0            0            2            1
#
#                   feature 703  feature 704
# id
# nf313a6a2ba5d8ea            0            0
# ne898d680d03f464            2            3
# n986fb66ab539cb7            2            3
# n3d14ff5f4be25e3            1            2
# n1ed8fc36eda9df0            4            1
# ...                       ...          ...
# nad4b893e7910343            2            3
# n4c483117a13d704            3            1
# nba238dc06d80658            1            3
# n5e84b8fff8e7781            4            2
# n37cfbcb6f5ef398            4            0
#
# [549254 rows x 707 columns]

# %% [markdown]
# Encoding the Numeric Values in the Target into corresponding labels (class 0 to class 4)

# %%
label_encoder = LabelEncoder()
label_encoder.fit(dataset['target'])
train_df['target'] = label_encoder.transform(train_df['target'])
val_df['target'] = label_encoder.transform(val_df['target'])

# %% [markdown]
# Label Map/Dictionary to store the mapping

# %%
labels_dict = {i: label_encoder.transform([i])[0] for i in label_encoder.classes_}
labels_dict
# Out:
# {0.0: 0, 0.25: 1, 0.5: 2, 0.75: 3, 1.0: 4}

# %%
train_df_x = train_df.drop(['target'], axis=1, inplace=False)
train_df_y = train_df['target']

# %%
train_df_x
# Out:
#                   era  feature 0  feature 1  feature 2  feature 3  feature 4  \
# id
# n02ccde8415c38aa  538          1          2          0          2          1
# n2304b3e75684be7  538          4          3          4          0          0
# n8f9f03f87006ca6  301          3          0          0          0          2
# n329f28c70b122ca  516          1          4          1          1          0
# neb7b6c30352e104  336          2          1          0          2          4
# ...               ...        ...        ...        ...        ...        ...
# n26ad4563c77aadd   40          3          2          1          2          3
# nd17176101e0c0d4  369          3          0          1          3          3
# n68766810d412555  500          4          3          3          2          2
# na53b191b95a22b5  474          4          2          2          2          3
# n7d36f87401b3463  472          2          2          1          4          1
#
#                   feature 5  feature 6  feature 7  feature 8  ...  \
# id                                                            ...
# n02ccde8415c38aa          2          0          3          4  ...
# n2304b3e75684be7          4          4          0          4  ...
# n8f9f03f87006ca6          1          4          4          3  ...
# n329f28c70b122ca          2          3          0          3  ...
# neb7b6c30352e104          3          4          4          0  ...
# ...                     ...        ...        ...        ...  ...
# n26ad4563c77aadd          2          3          2          0  ...
# nd17176101e0c0d4          2          1          2          1  ...
# n68766810d412555          4          2          4          0  ...
# na53b191b95a22b5          0          0          3          3  ...
# n7d36f87401b3463          1          2          1          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# n02ccde8415c38aa            4            4            1            4
# n2304b3e75684be7            2            2            4            3
# n8f9f03f87006ca6            0            2            3            1
# n329f28c70b122ca            4            1            4            3
# neb7b6c30352e104            2            4            3            4
# ...                       ...          ...          ...          ...
# n26ad4563c77aadd            2            2            4            4
# nd17176101e0c0d4            2            3            3            3
# n68766810d412555            0            2            3            0
# na53b191b95a22b5            3            3            1            4
# n7d36f87401b3463            1            3            1            1
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# n02ccde8415c38aa            0            1            0            4
# n2304b3e75684be7            0            3            1            0
# n8f9f03f87006ca6            4            1            0            1
# n329f28c70b122ca            4            1            2            2
# neb7b6c30352e104            4            3            2            4
# ...                       ...          ...          ...          ...
# n26ad4563c77aadd            1            4            2            1
# nd17176101e0c0d4            3            1            0            2
# n68766810d412555            0            2            1            2
# na53b191b95a22b5            4            2            0            1
# n7d36f87401b3463            1            1            3            2
#
#                   feature 703  feature 704
# id
# n02ccde8415c38aa            3            4
# n2304b3e75684be7            2            0
# n8f9f03f87006ca6            1            1
# n329f28c70b122ca            4            0
# neb7b6c30352e104            2            3
# ...                       ...          ...
# n26ad4563c77aadd            2            3
# nd17176101e0c0d4            0            4
# n68766810d412555            2            1
# na53b191b95a22b5            2            4
# n7d36f87401b3463            1            3
#
# [2197016 rows x 706 columns]

# %%
train_df_y
# Out:
# id
# n02ccde8415c38aa    2
# n2304b3e75684be7    3
# n8f9f03f87006ca6    1
# n329f28c70b122ca    2
# neb7b6c30352e104    2
#                    ..
# n26ad4563c77aadd    2
# nd17176101e0c0d4    2
# n68766810d412555    2
# na53b191b95a22b5    3
# n7d36f87401b3463    2
# Name: target, Length: 2197016, dtype: int64

# %%
val_df_x = val_df.drop(['target'], axis=1, inplace=False)
val_df_y = val_df['target']

# %%
val_df_x
# Out:
#                   era  feature 0  feature 1  feature 2  feature 3  feature 4  \
# id
# nf313a6a2ba5d8ea  308          1          0          4          0          0
# ne898d680d03f464  331          3          0          1          1          2
# n986fb66ab539cb7  237          1          3          0          2          3
# n3d14ff5f4be25e3  125          3          3          2          2          4
# n1ed8fc36eda9df0   98          4          4          0          1          1
# ...               ...        ...        ...        ...        ...        ...
# nad4b893e7910343  108          3          0          2          1          1
# n4c483117a13d704  151          1          3          0          2          2
# nba238dc06d80658  105          1          3          0          0          1
# n5e84b8fff8e7781  426          2          3          1          3          4
# n37cfbcb6f5ef398  475          3          1          4          0          0
#
#                   feature 5  feature 6  feature 7  feature 8  ...  \
# id                                                            ...
# nf313a6a2ba5d8ea          2          3          4          3  ...
# ne898d680d03f464          0          3          1          1  ...
# n986fb66ab539cb7          1          3          2          4  ...
# n3d14ff5f4be25e3          2          0          0          0  ...
# n1ed8fc36eda9df0          2          2          2          2  ...
# ...                     ...        ...        ...        ...  ...
# nad4b893e7910343          2          1          3          3  ...
# n4c483117a13d704          2          1          4          4  ...
# nba238dc06d80658          2          2          2          0  ...
# n5e84b8fff8e7781          1          2          1          2  ...
# n37cfbcb6f5ef398          2          1          4          2  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# nf313a6a2ba5d8ea            1            0            0            4
# ne898d680d03f464            1            4            2            0
# n986fb66ab539cb7            1            3            2            4
# n3d14ff5f4be25e3            4            3            3            4
# n1ed8fc36eda9df0            2            2            0            0
# ...                       ...          ...          ...          ...
# nad4b893e7910343            0            3            2            2
# n4c483117a13d704            0            3            1            2
# nba238dc06d80658            2            0            1            3
# n5e84b8fff8e7781            3            2            4            2
# n37cfbcb6f5ef398            2            1            3            2
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# nf313a6a2ba5d8ea            0            0            0            2
# ne898d680d03f464            2            2            1            1
# n986fb66ab539cb7            2            2            0            4
# n3d14ff5f4be25e3            1            2            0            1
# n1ed8fc36eda9df0            3            3            2            3
# ...                       ...          ...          ...          ...
# nad4b893e7910343            2            1            4            3
# n4c483117a13d704            4            3            2            4
# nba238dc06d80658            3            0            2            3
# n5e84b8fff8e7781            0            1            4            3
# n37cfbcb6f5ef398            0            0            2            1
#
#                   feature 703  feature 704
# id
# nf313a6a2ba5d8ea            0            0
# ne898d680d03f464            2            3
# n986fb66ab539cb7            2            3
# n3d14ff5f4be25e3            1            2
# n1ed8fc36eda9df0            4            1
# ...                       ...          ...
# nad4b893e7910343            2            3
# n4c483117a13d704            3            1
# nba238dc06d80658            1            3
# n5e84b8fff8e7781            4            2
# n37cfbcb6f5ef398            4            0
#
# [549254 rows x 706 columns]

# %%
val_df_y
# Out:
# id
# nf313a6a2ba5d8ea    2
# ne898d680d03f464    2
# n986fb66ab539cb7    2
# n3d14ff5f4be25e3    2
# n1ed8fc36eda9df0    3
#                    ..
# nad4b893e7910343    2
# n4c483117a13d704    2
# nba238dc06d80658    2
# n5e84b8fff8e7781    3
# n37cfbcb6f5ef398    3
# Name: target, Length: 549254, dtype: int64

# %%
del train_df
del val_df

gc.collect()
# Out:
# 0

# %% [markdown]
# Undersampling the training & validation fractions to ensure a more balanced dataset, since NumerAi is imbalanced/skewed towards a value of 0.5 (class 2)

# %%
undersample = RandomUnderSampler(random_state=42)

# %%
train_df_x_resampled, train_df_y_resampled = undersample.fit_resample(train_df_x, train_df_y)

# %%
val_df_x_resampled, val_df_y_resampled = undersample.fit_resample(val_df_x, val_df_y)

# %%
del train_df_x
del val_df_x
del train_df_y
del val_df_y

gc.collect()
# Out:
# 0

# %% [markdown]
# Converting data into floating type format

# %%
train_df_x_resampled = train_df_x_resampled.astype(np.float32)
val_df_x_resampled = val_df_x_resampled.astype(np.float32)

train_df_y_resampled = train_df_y_resampled.astype(np.float32)
val_df_y_resampled = val_df_y_resampled.astype(np.float32)

# %%
train_df_x_resampled
# Out:
#                     era  feature 0  feature 1  feature 2  feature 3  \
# id
# na07549d9cb0c978  247.0        2.0        4.0        0.0        3.0
# neba7f32ece3086e  365.0        0.0        3.0        2.0        4.0
# na7293ccee5af948  318.0        0.0        3.0        2.0        4.0
# nf38c63dadffa0a3  233.0        0.0        3.0        3.0        4.0
# ne31c4087a4bf180  435.0        0.0        3.0        1.0        2.0
# ...                 ...        ...        ...        ...        ...
# n4b1f1c5a85f36d3  267.0        2.0        1.0        1.0        3.0
# n54d459f5fd5dde5  250.0        4.0        1.0        1.0        0.0
# n6cf14468d0a8c44  526.0        0.0        4.0        2.0        0.0
# nb572d7239a224e5  451.0        4.0        2.0        4.0        0.0
# n04135d14c62dced  547.0        4.0        1.0        4.0        4.0
#
#                   feature 4  feature 5  feature 6  feature 7  feature 8  ...  \
# id                                                                       ...
# na07549d9cb0c978        1.0        1.0        0.0        0.0        2.0  ...
# neba7f32ece3086e        3.0        2.0        0.0        2.0        1.0  ...
# na7293ccee5af948        2.0        2.0        4.0        4.0        3.0  ...
# nf38c63dadffa0a3        0.0        2.0        4.0        4.0        1.0  ...
# ne31c4087a4bf180        4.0        0.0        1.0        3.0        0.0  ...
# ...                     ...        ...        ...        ...        ...  ...
# n4b1f1c5a85f36d3        1.0        1.0        3.0        4.0        2.0  ...
# n54d459f5fd5dde5        4.0        0.0        2.0        3.0        1.0  ...
# n6cf14468d0a8c44        0.0        4.0        1.0        1.0        3.0  ...
# nb572d7239a224e5        0.0        2.0        0.0        1.0        4.0  ...
# n04135d14c62dced        2.0        2.0        4.0        2.0        0.0  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# na07549d9cb0c978          3.0          3.0          4.0          1.0
# neba7f32ece3086e          2.0          1.0          3.0          3.0
# na7293ccee5af948          2.0          4.0          3.0          1.0
# nf38c63dadffa0a3          2.0          4.0          2.0          1.0
# ne31c4087a4bf180          1.0          2.0          3.0          2.0
# ...                       ...          ...          ...          ...
# n4b1f1c5a85f36d3          4.0          1.0          1.0          3.0
# n54d459f5fd5dde5          3.0          2.0          4.0          2.0
# n6cf14468d0a8c44          1.0          1.0          1.0          1.0
# nb572d7239a224e5          4.0          0.0          3.0          0.0
# n04135d14c62dced          2.0          4.0          0.0          0.0
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# na07549d9cb0c978          3.0          2.0          0.0          3.0
# neba7f32ece3086e          4.0          1.0          2.0          4.0
# na7293ccee5af948          4.0          2.0          0.0          4.0
# nf38c63dadffa0a3          1.0          1.0          2.0          4.0
# ne31c4087a4bf180          1.0          3.0          3.0          1.0
# ...                       ...          ...          ...          ...
# n4b1f1c5a85f36d3          1.0          3.0          0.0          4.0
# n54d459f5fd5dde5          3.0          3.0          1.0          3.0
# n6cf14468d0a8c44          3.0          3.0          1.0          1.0
# nb572d7239a224e5          0.0          1.0          4.0          0.0
# n04135d14c62dced          1.0          0.0          2.0          1.0
#
#                   feature 703  feature 704
# id
# na07549d9cb0c978          3.0          0.0
# neba7f32ece3086e          0.0          0.0
# na7293ccee5af948          1.0          1.0
# nf38c63dadffa0a3          3.0          4.0
# ne31c4087a4bf180          0.0          4.0
# ...                       ...          ...
# n4b1f1c5a85f36d3          3.0          3.0
# n54d459f5fd5dde5          2.0          0.0
# n6cf14468d0a8c44          3.0          4.0
# nb572d7239a224e5          0.0          0.0
# n04135d14c62dced          0.0          3.0
#
# [542805 rows x 706 columns]

# %%
val_df_x_resampled
# Out:
#                     era  feature 0  feature 1  feature 2  feature 3  \
# id
# ncdf26b8ce478ecf  574.0        1.0        0.0        4.0        0.0
# n4b4bf82266cda26  560.0        3.0        4.0        3.0        0.0
# n61d5d7b00dc995f  379.0        2.0        0.0        4.0        1.0
# n3162d17321ad479  569.0        0.0        4.0        4.0        0.0
# n10d10d843b6046c  292.0        0.0        4.0        2.0        0.0
# ...                 ...        ...        ...        ...        ...
# n051dbcb0462e3b6  114.0        2.0        2.0        2.0        0.0
# n40f6c9a87c5afcc    5.0        4.0        2.0        4.0        2.0
# need05ca67530d37  447.0        0.0        1.0        4.0        3.0
# nba162f3f2e3cfba  387.0        0.0        1.0        2.0        3.0
# nbd2485dc01a4c1a   28.0        0.0        2.0        3.0        0.0
#
#                   feature 4  feature 5  feature 6  feature 7  feature 8  ...  \
# id                                                                       ...
# ncdf26b8ce478ecf        0.0        3.0        2.0        3.0        0.0  ...
# n4b4bf82266cda26        3.0        2.0        2.0        4.0        4.0  ...
# n61d5d7b00dc995f        0.0        3.0        0.0        3.0        3.0  ...
# n3162d17321ad479        1.0        0.0        3.0        4.0        4.0  ...
# n10d10d843b6046c        1.0        3.0        0.0        2.0        1.0  ...
# ...                     ...        ...        ...        ...        ...  ...
# n051dbcb0462e3b6        0.0        2.0        4.0        2.0        2.0  ...
# n40f6c9a87c5afcc        1.0        2.0        3.0        2.0        0.0  ...
# need05ca67530d37        3.0        2.0        1.0        3.0        4.0  ...
# nba162f3f2e3cfba        3.0        3.0        2.0        0.0        0.0  ...
# nbd2485dc01a4c1a        2.0        2.0        1.0        2.0        4.0  ...
#
#                   feature 695  feature 696  feature 697  feature 698  \
# id
# ncdf26b8ce478ecf          1.0          1.0          0.0          4.0
# n4b4bf82266cda26          0.0          4.0          4.0          0.0
# n61d5d7b00dc995f          2.0          0.0          0.0          1.0
# n3162d17321ad479          2.0          2.0          2.0          1.0
# n10d10d843b6046c          2.0          2.0          3.0          1.0
# ...                       ...          ...          ...          ...
# n051dbcb0462e3b6          1.0          3.0          4.0          3.0
# n40f6c9a87c5afcc          2.0          3.0          2.0          4.0
# need05ca67530d37          2.0          0.0          3.0          3.0
# nba162f3f2e3cfba          1.0          0.0          4.0          3.0
# nbd2485dc01a4c1a          2.0          3.0          1.0          2.0
#
#                   feature 699  feature 700  feature 701  feature 702  \
# id
# ncdf26b8ce478ecf          0.0          0.0          3.0          0.0
# n4b4bf82266cda26          4.0          4.0          2.0          2.0
# n61d5d7b00dc995f          0.0          0.0          2.0          0.0
# n3162d17321ad479          4.0          2.0          2.0          0.0
# n10d10d843b6046c          1.0          4.0          3.0          2.0
# ...                       ...          ...          ...          ...
# n051dbcb0462e3b6          4.0          4.0          2.0          3.0
# n40f6c9a87c5afcc          0.0          4.0          2.0          3.0
# need05ca67530d37          2.0          1.0          0.0          0.0
# nba162f3f2e3cfba          3.0          1.0          4.0          1.0
# nbd2485dc01a4c1a          3.0          2.0          2.0          1.0
#
#                   feature 703  feature 704
# id
# ncdf26b8ce478ecf          0.0          0.0
# n4b4bf82266cda26          4.0          0.0
# n61d5d7b00dc995f          0.0          0.0
# n3162d17321ad479          4.0          0.0
# n10d10d843b6046c          0.0          2.0
# ...                       ...          ...
# n051dbcb0462e3b6          4.0          2.0
# n40f6c9a87c5afcc          0.0          0.0
# need05ca67530d37          0.0          4.0
# nba162f3f2e3cfba          0.0          3.0
# nbd2485dc01a4c1a          4.0          4.0
#
# [135535 rows x 706 columns]

# %%
train_df_y_resampled
# Out:
# id
# na07549d9cb0c978    0.0
# neba7f32ece3086e    0.0
# na7293ccee5af948    0.0
# nf38c63dadffa0a3    0.0
# ne31c4087a4bf180    0.0
#                    ...
# n4b1f1c5a85f36d3    4.0
# n54d459f5fd5dde5    4.0
# n6cf14468d0a8c44    4.0
# nb572d7239a224e5    4.0
# n04135d14c62dced    4.0
# Name: target, Length: 542805, dtype: float32

# %%
train_df_y_resampled.is_monotonic_increasing
# Out:
# True

# %%
val_df_y_resampled
# Out:
# id
# ncdf26b8ce478ecf    0.0
# n4b4bf82266cda26    0.0
# n61d5d7b00dc995f    0.0
# n3162d17321ad479    0.0
# n10d10d843b6046c    0.0
#                    ...
# n051dbcb0462e3b6    4.0
# n40f6c9a87c5afcc    4.0
# need05ca67530d37    4.0
# nba162f3f2e3cfba    4.0
# nbd2485dc01a4c1a    4.0
# Name: target, Length: 135535, dtype: float32

# %% [markdown]
# Function to extract the highly correlated features with respect to the predictions

# %%
def get_highly_correlated_features(x: pd.DataFrame, y, correlation_threshold: float = 0.03) -> list:
	if not isinstance(y, pd.Series):
		y = pd.Series(y, index=x.index)

	correlations = x.apply(lambda feature: feature.corr(y))
	highly_correlated_features = correlations[correlations.abs() > correlation_threshold].index.tolist()
	
	return highly_correlated_features

# %% [markdown]
# Function to neutralise the effect of highly correlated features with respect to the predictions by subtracting a proportion from the predictions

# %%
def neutralize_predictions(predictions: np.ndarray, x: pd.DataFrame, features_to_neutralize: list, proportion: float = 1.0) -> np.ndarray:
	predictions_df = pd.DataFrame(predictions, columns=['prediction'], index=x.index)
	neutralized_preds = predictions_df['prediction'].copy()
	
	for feature in features_to_neutralize:
		neutralizer = x[feature]
		adjustment = proportion * (neutralizer.dot(predictions_df['prediction']) / neutralizer.dot(neutralizer)) * neutralizer
		neutralized_preds -= adjustment
	# neutralizer = x
	# print(neutralizer.shape, neutralized_preds.shape)
	# adjustment = proportion * (neutralizer.dot(predictions_df['prediction']) / neutralizer.dot(neutralizer)) * neutralizer
	# neutralized_preds -= adjustment
   
	return neutralized_preds.values

# %% [markdown]
# Calculating the class weights to ensure a more balanced training for some of the weak classifiers/experts

# %%
classes = np.unique(train_df_y_resampled)
class_weights = compute_class_weight('balanced', classes=classes, y=train_df_y_resampled)
class_weight_dict = {cls: weight for cls, weight in zip(classes, class_weights)}
sample_weights = np.array([class_weight_dict[label] for label in train_df_y_resampled])

# %% [markdown]
# Evaluation Functions

# %% [markdown]
# Function to compute Label Frequencies

# %%
def label_frequency(predictions):
	unique, counts = np.unique(predictions, return_counts=True)
	label_frequencies = dict(zip(unique, counts))
	print("Label frequencies:", label_frequencies)

# %% [markdown]
# Function to compute NumerAi Correlation

# %%
def numerai_corr(preds, target):
	ranked_preds = (preds.rank(method="average").values - 0.5) / preds.count()
	gauss_ranked_preds = stats.norm.ppf(ranked_preds)

	centered_target = target - target.mean()

	preds_p15 = np.sign(gauss_ranked_preds) * np.abs(gauss_ranked_preds) ** 1.5
	target_p15 = np.sign(centered_target) * np.abs(centered_target) ** 1.5

	return np.corrcoef(preds_p15, target_p15)[0, 1]

# %% [markdown]
# EXPERT-1 (XGBOOST CLASSIFIER)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# expert1 = xgb.XGBClassifier(
#     objective='multi:softprob',
#     num_class=5,
#     n_estimators=1000,
#     max_depth=10,
#     learning_rate=0.01,
#     random_state=42,
#     subsample=0.8,
#     colsample_bytree=0.8,
#     gamma=2,
#     min_child_weight=5,
#     reg_alpha=0.1,
#     reg_lambda=1.0,
#     eval_metric='mlogloss',
#     use_label_encoder=False
# )

# expert1.fit(train_df_x_resampled, train_df_y_resampled, sample_weight=sample_weights)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert1.pkl', 'rb') as f:
	expert1 = pickle.load(f)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Saving the Model

# %%
# with open('numerai_expert1.pkl', 'wb') as f:
# 	pickle.dump(expert1, f)
# print("Expert1 saved successfully!")
# Out:
# Expert1 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-1

# %%
expert1_pred = expert1.predict(val_df_x_resampled)

# %%
expert1_pred
# Out:
# array([0, 0, 0, ..., 4, 4, 1])

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert1_pred)
pd.Series(expert1_pred).value_counts()
# Out:
# Label frequencies: {0: 31003, 1: 19210, 2: 34192, 3: 20200, 4: 30930}
# 2    34192
# 0    31003
# 4    30930
# 3    20200
# 1    19210
# Name: count, dtype: int64

# %%
acc = accuracy_score(expert1_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.4346847677721622

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert1_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: []

# %%
# expert1_pred = neutralize_predictions(predictions=expert1_pred, x=val_df_x_resampled, features_to_neutralize=highly_correlated_features, proportion=0.01)
expert1_pred = neutralize_predictions(predictions=expert1_pred, x=val_df_x_resampled, features_to_neutralize=feature_set, proportion=0.0001)
print("Neutralized predictions, Expert1:", expert1_pred)
# Out:
# Neutralized predictions, Expert1: [-0.07595696 -0.11631754 -0.07923166 ...  3.90693126  3.90595877
#   0.90671264]

# %% [markdown]
# EXPERT-2 (RANDOM FOREST CLASSIFIER)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# expert2 = RandomForestClassifier(
#     n_estimators=1000,              
#     max_depth=10,                   
#     min_samples_split=5,            
#     min_samples_leaf=4,            
#     max_features='sqrt',           
#     bootstrap=True,               
#     class_weight='balanced',       
#     n_jobs=-1,                     
#     random_state=42,               
#     max_samples=0.9,               
#     oob_score=True,                
#     criterion='gini',              
#     verbose=1                      
# )

# expert2.fit(train_df_x_resampled, train_df_y_resampled, sample_weight=sample_weights)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 776 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:  8.6min finished
# RandomForestClassifier(class_weight='balanced', max_depth=10, max_samples=0.9,
#                        min_samples_leaf=4, min_samples_split=5,
#                        n_estimators=1000, n_jobs=-1, oob_score=True,
#                        random_state=42, verbose=1)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert2.pkl', 'rb') as f:
	expert2 = pickle.load(f)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Saving the Model

# %%
# with open('numerai_expert2.pkl', 'wb') as f:
# 	pickle.dump(expert2, f)
# print("Expert2 saved successfully!")
# Out:
# Expert2 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-2

# %%
expert2_pred = expert2.predict(val_df_x_resampled)
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=12)]: Done 776 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=12)]: Done 1000 out of 1000 | elapsed:    4.1s finished

# %%
expert2_pred
# Out:
# array([0., 3., 0., ..., 4., 3., 1.], dtype=float32)

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert2_pred)
# Out:
# Label frequencies: {0.0: 30049, 1.0: 12036, 2.0: 47796, 3.0: 12200, 4.0: 33454}

# %%
acc = accuracy_score(expert2_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.3458442468735013

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert2_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: ['feature 42', 'feature 56', 'feature 61', 'feature 64', 'feature 65', 'feature 69', 'feature 74', 'feature 76', 'feature 81', 'feature 88', 'feature 91', 'feature 101', 'feature 113', 'feature 126', 'feature 127', 'feature 129', 'feature 133', 'feature 142', 'feature 157', 'feature 160', 'feature 168', 'feature 172', 'feature 184', 'feature 200', 'feature 208', 'feature 222', 'feature 232', 'feature 246', 'feature 263', 'feature 268', 'feature 276', 'feature 296', 'feature 302', 'feature 306', 'feature 329', 'feature 335', 'feature 346', 'feature 350', 'feature 352', 'feature 374', 'feature 406', 'feature 423', 'feature 424', 'feature 428', 'feature 431', 'feature 437', 'feature 451', 'feature 455', 'feature 459', 'feature 466', 'feature 475', 'feature 484', 'feature 501', 'feature 514', 'feature 537', 'feature 545', 'feature 546', 'feature 547', 'feature 552', 'feature 566', 'feature 573', 'feature 582', 'feature 588', 'feature 593', 'feature 615', 'feature 625', 'feature 627', 'feature 653', 'feature 657', 'feature 662', 'feature 663', 'feature 665', 'feature 674', 'feature 676', 'feature 692', 'feature 693', 'feature 703']

# %%
expert2_pred = neutralize_predictions(predictions=expert2_pred, x=val_df_x_resampled, features_to_neutralize=feature_set, proportion=0.0001)
print("Neutralized predictions, Expert2:", expert2_pred)
# Out:
# Neutralized predictions, Expert2: [-0.07808787  2.8796296  -0.08121528 ...  3.904295    2.9033084
#   0.9033051 ]

# %% [markdown]
# EXPERT-3 (ADABOOST CLASSIFIER with DECISION TREE CLASSIFIER as BASE ESTIMATOR)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# base_estimator = DecisionTreeClassifier(
#     class_weight='balanced',                
#     max_features='sqrt',
#     max_depth=3,    
#     random_state=42         
# )

# expert3 = AdaBoostClassifier(
#     estimator=base_estimator, 
#     n_estimators=1000,             
#     learning_rate=0.01,           
#     algorithm='SAMME.R',           
#     random_state=42               
# )

# expert3.fit(train_df_x_resampled, train_df_y_resampled)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(class_weight='balanced',
#                                                     max_depth=3,
#                                                     max_features='sqrt',
#                                                     random_state=42),
#                    learning_rate=0.01, n_estimators=1000, random_state=42)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert3.pkl', 'rb') as f:
	expert3 = pickle.load(f)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Saving the Model

# %%
# with open('numerai_expert3.pkl', 'wb') as f:
# 	pickle.dump(expert3, f)
# print("Expert3 saved successfully!")
# Out:
# Expert3 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-3

# %%
expert3_pred = expert3.predict(val_df_x_resampled)

# %%
expert3_pred
# Out:
# array([0., 3., 4., ..., 4., 1., 1.], dtype=float32)

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert3_pred)
# Out:
# Label frequencies: {0.0: 27770, 1.0: 13593, 2.0: 44088, 3.0: 16264, 4.0: 33820}

# %%
acc = accuracy_score(expert3_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.29076622274689196

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert3_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: ['feature 4', 'feature 28', 'feature 36', 'feature 39', 'feature 49', 'feature 57', 'feature 69', 'feature 72', 'feature 124', 'feature 131', 'feature 133', 'feature 145', 'feature 146', 'feature 151', 'feature 157', 'feature 158', 'feature 159', 'feature 168', 'feature 175', 'feature 192', 'feature 219', 'feature 221', 'feature 244', 'feature 245', 'feature 254', 'feature 257', 'feature 268', 'feature 279', 'feature 299', 'feature 333', 'feature 339', 'feature 342', 'feature 344', 'feature 351', 'feature 382', 'feature 397', 'feature 402', 'feature 422', 'feature 427', 'feature 437', 'feature 442', 'feature 444', 'feature 458', 'feature 470', 'feature 477', 'feature 501', 'feature 509', 'feature 512', 'feature 533', 'feature 535', 'feature 543', 'feature 546', 'feature 547', 'feature 551', 'feature 557', 'feature 558', 'feature 582', 'feature 587', 'feature 589', 'feature 596', 'feature 618', 'feature 632', 'feature 639', 'feature 649', 'feature 656', 'feature 657', 'feature 667', 'feature 668', 'feature 675', 'feature 676', 'feature 677']

# %%
expert3_pred = neutralize_predictions(predictions=expert3_pred, x=val_df_x_resampled, features_to_neutralize=feature_set, proportion=0.0001)
print("Neutralized predictions, Expert3:", expert3_pred)
# Out:
# Neutralized predictions, Expert3: [-0.08017288  2.876645    3.9162774  ...  3.9016256   0.90057355
#   0.901381  ]

# %% [markdown]
# EXPERT-4 (LOGISTIC REGRESSION)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# expert4 = LogisticRegression(
#     class_weight='balanced',
#     random_state=42,
#     solver='saga',
#     penalty='l2',
#     C=0.25,
#     tol=1e-4,
#     max_iter=500,
#     n_jobs=-1
# )

# expert4.fit(train_df_x_resampled, train_df_y_resampled)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert4.pkl', 'rb') as f:
	expert4 = pickle.load(f)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Saving the Model

# %%
# with open('numerai_expert4.pkl', 'wb') as f:
# 	pickle.dump(expert4, f)
# print("Expert4 saved successfully!")
# Out:
# Expert4 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-4

# %%
expert4_pred = expert4.predict(val_df_x_resampled)

# %%
expert4_pred
# Out:
# array([4., 1., 0., ..., 0., 3., 1.], dtype=float32)

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert4_pred)
# Out:
# Label frequencies: {0.0: 31387, 1.0: 15920, 2.0: 41091, 3.0: 16596, 4.0: 30541}

# %%
acc = accuracy_score(expert4_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.29539233408344706

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert4_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: ['feature 17', 'feature 45', 'feature 72', 'feature 133', 'feature 168', 'feature 254', 'feature 286', 'feature 287', 'feature 288', 'feature 363', 'feature 372', 'feature 379', 'feature 389', 'feature 431', 'feature 517', 'feature 546', 'feature 618', 'feature 640', 'feature 657', 'feature 666', 'feature 671', 'feature 676', 'feature 698']

# %%
expert4_pred = neutralize_predictions(predictions=expert4_pred, x=val_df_x_resampled, features_to_neutralize=feature_set, proportion=0.0001)
print("Neutralized predictions, Expert4:", expert4_pred)
# Out:
# Neutralized predictions, Expert4: [ 3.9244518  0.884169  -0.0788121 ... -0.0927045  2.9063764  0.9071653]

# %% [markdown]
# EXPERT-5 (CATBOOST CLASSIFIER)

# %%
'''
Commented out because the model is already trained over this & saved
'''

# expert5 = CatBoostClassifier(
#     auto_class_weights='Balanced',
#     random_state=42,
#     iterations=500,
#     learning_rate=0.1,
#     depth=5,
#     l2_leaf_reg=3,
#     eval_metric='MultiClass',
#     early_stopping_rounds=20,
#     verbose=100
# )

# expert5.fit(train_df_x_resampled, train_df_y_resampled)

# %% [markdown]
# Loading the Model

# %%
with open('numerai_expert5.pkl', 'rb') as f:
	expert5 = pickle.load(f)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %% [markdown]
# Saving the Model

# %%
# with open('numerai_expert5.pkl', 'wb') as f:
# 	pickle.dump(expert5, f)
# print("Expert5 saved successfully!")
# Out:
# Expert5 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-5

# %%
expert5_pred = expert5.predict(val_df_x_resampled)

# %%
if expert5_pred.ndim > 1:
	expert5_pred = expert5_pred.ravel()

# %%
expert5_pred
# Out:
# array([0., 3., 0., ..., 4., 3., 1.])

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert5_pred)
# Out:
# Label frequencies: {0.0: 30896, 1.0: 16431, 2.0: 38741, 3.0: 17887, 4.0: 31580}

# %%
acc = accuracy_score(expert5_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.3158372376139005

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert5_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: ['feature 17', 'feature 45', 'feature 69', 'feature 72', 'feature 133', 'feature 168', 'feature 254', 'feature 268', 'feature 286', 'feature 287', 'feature 288', 'feature 363', 'feature 437', 'feature 477', 'feature 517', 'feature 546', 'feature 640', 'feature 657', 'feature 671', 'feature 676']

# %%
expert5_pred = neutralize_predictions(predictions=expert5_pred, x=val_df_x_resampled, features_to_neutralize=feature_set, proportion=0.0001)
print("Neutralized predictions, Expert5:", expert5_pred)
# Out:
# Neutralized predictions, Expert5: [-0.07664246  2.88242117 -0.08001118 ...  3.90591894  2.90498368
#   0.90572775]

# %% [markdown]
# EXPERT-6 (HISTOGRAM-BASED GRADIENT BOOST CLASSIFIER)

# %%
'''
Commented out because the model is already trained over this & saved
'''

expert6 = HistGradientBoostingClassifier(
    class_weight='balanced',
    random_state=42,
    learning_rate=0.001,
    max_iter=100,
    max_depth=10,
    min_samples_leaf=20,
    max_leaf_nodes=40,
    l2_regularization=1.0,
    max_bins=255,
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=50,
    scoring='roc_auc_ovr',
    loss='log_loss',
    verbose=1
)

expert6.fit(train_df_x_resampled, train_df_y_resampled, sample_weight=sample_weights)
# Out:
# Binning 2.759 GB of training data: 7.517 s
# Binning 0.307 GB of validation data: 0.212 s
# Fitting gradient boosted rounds:
# [1/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61548, val score: 0.61291, in 2.766s
# [2/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61554, val score: 0.61299, in 2.763s
# [3/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61553, val score: 0.61297, in 2.753s
# [4/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61558, val score: 0.61297, in 2.756s
# [5/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61572, val score: 0.61300, in 2.744s
# [6/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61581, val score: 0.61309, in 2.749s
# [7/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61583, val score: 0.61310, in 2.756s
# [8/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61599, val score: 0.61320, in 2.783s
# [9/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61599, val score: 0.61325, in 2.757s
# [10/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61607, val score: 0.61328, in 2.789s
# [11/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61599, val score: 0.61332, in 2.746s
# [12/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61605, val score: 0.61333, in 2.827s
# [13/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61609, val score: 0.61337, in 2.743s
# [14/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61611, val score: 0.61338, in 2.751s
# [15/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61612, val score: 0.61343, in 2.756s
# [16/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61614, val score: 0.61347, in 2.777s
# [17/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61616, val score: 0.61349, in 2.766s
# [18/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61618, val score: 0.61355, in 2.750s
# [19/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61620, val score: 0.61353, in 2.736s
# [20/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61622, val score: 0.61356, in 2.799s
# [21/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61629, val score: 0.61360, in 2.762s
# [22/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61625, val score: 0.61361, in 2.750s
# [23/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61630, val score: 0.61365, in 2.731s
# [24/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61631, val score: 0.61366, in 2.817s
# [25/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61635, val score: 0.61369, in 2.754s
# [26/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61631, val score: 0.61369, in 2.762s
# [27/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61637, val score: 0.61372, in 2.756s
# [28/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61638, val score: 0.61373, in 2.747s
# [29/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61635, val score: 0.61374, in 2.750s
# [30/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61639, val score: 0.61375, in 2.750s
# [31/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61642, val score: 0.61376, in 2.741s
# [32/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61646, val score: 0.61377, in 2.752s
# [33/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61648, val score: 0.61381, in 2.744s
# [34/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61648, val score: 0.61381, in 2.749s
# [35/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61653, val score: 0.61385, in 2.752s
# [36/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61658, val score: 0.61390, in 2.739s
# [37/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61661, val score: 0.61395, in 2.766s
# [38/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61668, val score: 0.61400, in 2.740s
# [39/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61673, val score: 0.61404, in 2.749s
# [40/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61677, val score: 0.61408, in 2.751s
# [41/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61681, val score: 0.61413, in 2.752s
# [42/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61689, val score: 0.61418, in 2.793s
# [43/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61699, val score: 0.61424, in 2.838s
# [44/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61701, val score: 0.61427, in 2.730s
# [45/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61716, val score: 0.61435, in 2.745s
# [46/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61726, val score: 0.61442, in 2.753s
# [47/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61734, val score: 0.61444, in 2.736s
# [48/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61746, val score: 0.61453, in 2.755s
# [49/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61747, val score: 0.61454, in 2.753s
# [50/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61761, val score: 0.61461, in 2.737s
# [51/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61766, val score: 0.61463, in 2.753s
# [52/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61772, val score: 0.61467, in 2.722s
# [53/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61782, val score: 0.61472, in 2.744s
# [54/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61787, val score: 0.61476, in 2.792s
# [55/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61792, val score: 0.61478, in 2.742s
# [56/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61796, val score: 0.61481, in 2.734s
# [57/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61805, val score: 0.61486, in 2.792s
# [58/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61810, val score: 0.61489, in 2.734s
# [59/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61815, val score: 0.61492, in 2.733s
# [60/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61821, val score: 0.61497, in 2.732s
# [61/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61828, val score: 0.61500, in 2.755s
# [62/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61831, val score: 0.61502, in 2.739s
# [63/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61837, val score: 0.61505, in 2.734s
# [64/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61846, val score: 0.61509, in 2.725s
# [65/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61849, val score: 0.61510, in 2.746s
# [66/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61860, val score: 0.61516, in 2.726s
# [67/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61861, val score: 0.61518, in 2.768s
# [68/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61867, val score: 0.61521, in 2.717s
# [69/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61872, val score: 0.61523, in 2.745s
# [70/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61878, val score: 0.61527, in 2.725s
# [71/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61881, val score: 0.61528, in 2.748s
# [72/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61888, val score: 0.61532, in 2.738s
# [73/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61891, val score: 0.61533, in 2.767s
# [74/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61896, val score: 0.61536, in 2.725s
# [75/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61902, val score: 0.61540, in 2.735s
# [76/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61905, val score: 0.61541, in 2.787s
# [77/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61909, val score: 0.61543, in 2.725s
# [78/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61912, val score: 0.61546, in 2.730s
# [79/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61918, val score: 0.61549, in 2.755s
# [80/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61918, val score: 0.61551, in 2.736s
# [81/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61925, val score: 0.61554, in 2.741s
# [82/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61928, val score: 0.61557, in 2.741s
# [83/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61929, val score: 0.61559, in 2.806s
# [84/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61935, val score: 0.61563, in 2.734s
# [85/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61939, val score: 0.61566, in 2.774s
# [86/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61943, val score: 0.61569, in 2.776s
# [87/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61945, val score: 0.61571, in 2.807s
# [88/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61950, val score: 0.61574, in 2.750s
# [89/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61952, val score: 0.61577, in 2.818s
# [90/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61959, val score: 0.61579, in 2.764s
# [91/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61962, val score: 0.61583, in 2.745s
# [92/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61965, val score: 0.61585, in 2.738s
# [93/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61967, val score: 0.61587, in 2.732s
# [94/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61973, val score: 0.61591, in 2.783s
# [95/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61975, val score: 0.61593, in 2.749s
# [96/100] 5 trees, 200 leaves (40 on avg), max depth = 8, train score: 0.61979, val score: 0.61596, in 2.725s
# [97/100] 5 trees, 200 leaves (40 on avg), max depth = 10, train score: 0.61982, val score: 0.61598, in 2.752s
# [98/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61986, val score: 0.61601, in 2.710s
# [99/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61988, val score: 0.61604, in 2.813s
# [100/100] 5 trees, 200 leaves (40 on avg), max depth = 9, train score: 0.61993, val score: 0.61607, in 2.733s
# Fit 500 trees in 286.646 s, (20000 total leaves)
# Time spent computing histograms: 259.959s
# Time spent finding best splits:  1.393s
# Time spent applying splits:      2.401s
# Time spent predicting:           0.453s
# HistGradientBoostingClassifier(class_weight='balanced', early_stopping=True,
#                                l2_regularization=1.0, learning_rate=0.001,
#                                max_depth=10, max_leaf_nodes=40,
#                                n_iter_no_change=50, random_state=42,
#                                scoring='roc_auc_ovr', verbose=1)

# %% [markdown]
# Loading the Model

# %%
# with open('numerai_expert6.pkl', 'rb') as f:
# 	expert6 = pickle.load(f)
# print("Model loaded successfully!")

# %% [markdown]
# Saving the Model

# %%
with open('numerai_expert6.pkl', 'wb') as f:
	pickle.dump(expert6, f)
print("Expert6 saved successfully!")
# Out:
# Expert6 saved successfully!

# %% [markdown]
# Generating Predictions from Expert-6

# %%
expert6_pred = expert6.predict(val_df_x_resampled)

# %%
expert6_pred
# Out:
# array([0., 1., 4., ..., 3., 2., 0.], dtype=float32)

# %% [markdown]
# Computing Label Frequencies in Prediction, Accuracy, Highly Correlated Features & Neutralising the Predictions

# %%
label_frequency(expert6_pred)
# Out:
# Label frequencies: {0.0: 31091, 1.0: 14463, 2.0: 43072, 3.0: 15408, 4.0: 31501}

# %%
acc = accuracy_score(expert6_pred, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.2776552182093186

# %%
highly_correlated_features = get_highly_correlated_features(val_df_x_resampled, expert6_pred, correlation_threshold=0.09)
print("Highly correlated features:", highly_correlated_features)
# Out:
# Highly correlated features: []

# %%
expert6_pred = neutralize_predictions(predictions=expert6_pred, x=val_df_x_resampled, features_to_neutralize=feature_set, proportion=0.0001)
print("Neutralized predictions, Expert6:", expert6_pred)
# Out:
# Neutralized predictions, Expert6: [-0.07617297  0.8830295   3.9206052  ...  2.9066734   1.9055746
#  -0.09360538]

# %% [markdown]
# META-MODEL (LIGHTGBM)

# %%
meta_model = lgb.LGBMRegressor(
	objective='regression',
	n_estimators=10000,
	learning_rate=0.01,
	max_depth=10,
	num_leaves=2**10,
	colsample_bytree=0.1,
	random_state=42
)

# %%
meta_val_x = np.column_stack((expert1_pred, expert2_pred, expert3_pred, expert4_pred, expert5_pred, expert6_pred))

# %%
meta_val_x
# Out:
# array([[-0.07595696, -0.07808787, -0.08017288,  3.92445183, -0.07664246,
#         -0.07617297],
#        [-0.11631754,  2.87962961,  2.87664509,  0.88416898,  2.88242117,
#          0.88302952],
#        [-0.07923166, -0.08121528,  3.91627741, -0.0788121 , -0.08001118,
#          3.92060518],
#        ...,
#        [ 3.90693126,  3.90429497,  3.90162563, -0.0927045 ,  3.90591894,
#          2.90667343],
#        [ 3.90595877,  2.90330839,  0.90057355,  2.90637636,  2.90498368,
#          1.90557456],
#        [ 0.90671264,  0.90330511,  0.90138102,  0.90716529,  0.90572775,
#         -0.09360538]])

# %%
meta_model.fit(meta_val_x, val_df_y_resampled)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000268 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 135535, number of used features: 6
# [LightGBM] [Info] Start training from score 2.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor(colsample_bytree=0.1, learning_rate=0.01, max_depth=10,
#               n_estimators=10000, num_leaves=1024, objective='regression',
#               random_state=42)

# %% [markdown]
# Loading the Meta-Model

# %%
with open('numerai_meta_model.pkl', 'rb') as f:
	meta_model = pickle.load(f)
print("Meta Model loaded successfully!")

# %% [markdown]
# Saving the Meta-Model

# %%
with open('numerai_meta_model.pkl', 'wb') as f:
	pickle.dump(meta_model, f)
print("Meta Model saved successfully!")
# Out:
# Meta Model saved successfully!

# %% [markdown]
# Testing Performance on Trained Data

# %%
meta_val_x.shape
# Out:
# (135535, 6)

# %%
meta_y_pred = meta_model.predict(meta_val_x)

# %%
meta_y_pred
# Out:
# array([1.19165536, 1.35415312, 0.78915697, ..., 3.20116129, 2.93791834,
#        1.72927999])

# %%
bins = [0.5, 1.5, 2.5, 3.5]

rounded_predictions = np.digitize(meta_y_pred, bins)

# %%
rounded_predictions
# Out:
# array([1, 1, 1, ..., 3, 3, 2])

# %% [markdown]
# Computing Relevant Evaluation Metrics

# %%
label_frequency(rounded_predictions)
# Out:
# Label frequencies: {0: 24, 1: 36974, 2: 61685, 3: 36843, 4: 9}

# %%
acc = accuracy_score(rounded_predictions, val_df_y_resampled)
print("Accuracy on Training Set: ", acc)
# Out:
# Accuracy on Training Set:  0.25906223484708746

# %% [markdown]
# Pearson's Correlation

# %%
pearson_corr, _ = stats.pearsonr(rounded_predictions, val_df_y_resampled)
print("Pearson Correlation:", pearson_corr)
# Out:
# Pearson Correlation: 0.45708163745698094

# %% [markdown]
# Computing the NumerAi's Correlation Metric

# %%
rounded_predictions = pd.Series(rounded_predictions)

# %%
actual_corr = numerai_corr(rounded_predictions, val_df_y_resampled)
actual_corr
# Out:
# 0.46039025225739605
